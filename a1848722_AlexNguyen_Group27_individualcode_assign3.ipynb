# %% [markdown]
# # Assignment 3A: Frequent Patterns - Individual code
#
# \Alex Nguyen
#
# **Business Scenario**
#
# You are working in a team of developers for a grocery store. The store manager noticed that some items are often bought together. The manager wants to find out exactly what items customers buy most often together in one basket (we call them itemsets). This information will be used to place itemsets close together, so that customers can find them quickly, which in turn may increase sales.
#
# After analysing the problem, your team has discovered that once frequent itemsets are identified, it is also possible to recommend products from these itemsets to customers on the store website.
#
# Your team, being knowledgeable of both frequent itemsets mining and recommendation systems, wants to go even further: you want to test other well-known recommendation methods, such as collaborative filtering, to see which recommendation method works better.
#
# The store collects details about customers’ buying habits through a loyalty programme and your team is given access to the representative dataset. The system you build, however, should scale to around one million customer transactions.
#
# The project has been approved by the store management, so you are ready to start building the system which can help to significantly increase sales.

# %% [markdown]
# ## Task 1: Patterns
#
# Write code in Python to mine frequent patterns from the training dataset with pattern mining algorithm discussed in the course - FP-growth.
#
# At the end of this task, you should have a system which can take raw input data and produce a series of patterns (and some kind of good/bad quality of the patterns).

# %% [markdown]
# ### 0. Install & load library

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

# %% [markdown]
# ### 1. Load data

# %%
train_data = pd.read_csv('Groceries data train.csv', header=0)
train_data
# Out:
#        Member_number        Date  itemDescription  year  month  day  \
# 0               3021  30/01/2015      frankfurter  2015      1   30
# 1               1292  24/10/2015             pork  2015     10   24
# 2               4206   4/04/2014  root vegetables  2014      4    4
# 3               4369  25/08/2015           onions  2015      8   25
# 4               1522   1/07/2014          waffles  2014      7    1
# ...              ...         ...              ...   ...    ...  ...
# 26995           4206  14/01/2014       rolls/buns  2014      1   14
# 26996           1660  15/06/2014    domestic eggs  2014      6   15
# 26997           1595  10/05/2015       liver loaf  2015      5   10
# 26998           3231  31/03/2015          sausage  2015      3   31
# 26999           2550   7/12/2014      canned beer  2014     12    7
#
#        day_of_week
# 0                4
# 1                5
# 2                4
# 3                1
# 4                1
# ...            ...
# 26995            1
# 26996            6
# 26997            6
# 26998            1
# 26999            6
#
# [27000 rows x 7 columns]

# %% [markdown]
# ### 2. Check itemsets

# %%
# check type of data
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27000 entries, 0 to 26999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    27000 non-null  int64
#  1   Date             27000 non-null  object
#  2   itemDescription  27000 non-null  object
#  3   year             27000 non-null  int64
#  4   month            27000 non-null  int64
#  5   day              27000 non-null  int64
#  6   day_of_week      27000 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 1.4+ MB

# %%
# check data value
train_data.describe()
# Out:
#        Member_number          year         month           day   day_of_week
# count   27000.000000  27000.000000  27000.000000  27000.000000  27000.000000
# mean     3002.872667   2014.529037      6.485074     15.744444      3.020852
# std      1153.928123      0.499165      3.431239      8.784553      1.987826
# min      1000.000000   2014.000000      1.000000      1.000000      0.000000
# 25%      2003.000000   2014.000000      4.000000      8.000000      1.000000
# 50%      3002.000000   2015.000000      6.000000     16.000000      3.000000
# 75%      4010.000000   2015.000000      9.000000     23.000000      5.000000
# max      5000.000000   2015.000000     12.000000     31.000000      6.000000

# %%
# check item
train_data['itemDescription'].unique()
# Out:
# array(['frankfurter', 'pork', 'root vegetables', 'onions', 'waffles',
#        'cereals', 'yogurt', 'sausage', 'rolls/buns', 'chocolate',
#        'whipped/sour cream', 'butter', 'curd', 'frozen meals',
#        'whole milk', 'tropical fruit', 'sugar', 'specialty cheese',
#        'other vegetables', 'fruit/vegetable juice', 'misc. beverages',
#        'frozen vegetables', 'spices', 'coffee', 'cream cheese ',
#        'red/blush wine', 'dessert', 'long life bakery product',
#        'domestic eggs', 'abrasive cleaner', 'berries',
#        'liquor (appetizer)', 'semi-finished bread', 'newspapers',
#        'beverages', 'beef', 'female sanitary products', 'salt', 'soda',
#        'sauces', 'oil', 'snack products', 'brown bread',
#        'hygiene articles', 'artif. sweetener', 'bottled beer',
#        'canned beer', 'hamburger meat', 'liver loaf', 'soups',
#        'pip fruit', 'hard cheese', 'shopping bags', 'canned vegetables',
#        'napkins', 'citrus fruit', 'margarine', 'pasta', 'salty snack',
#        'candles', 'cat food', 'meat', 'candy', 'condensed milk',
#        'UHT-milk', 'chewing gum', 'chicken', 'soft cheese', 'pastry',
#        'specialty chocolate', 'packaged fruit/vegetables',
#        'bottled water', 'cling film/bags', 'processed cheese', 'mustard',
#        'seasonal products', 'ham', 'herbs', 'white bread', 'mayonnaise',
#        'dental care', 'grapes', 'fish', 'nut snack', 'pickled vegetables',
#        'butter milk', 'finished products', 'dishes', 'frozen fish',
#        'dish cleaner', 'frozen dessert', 'flower (seeds)',
#        'male cosmetics', 'white wine', 'frozen chicken', 'instant coffee',
#        'pot plants', 'nuts/prunes', 'rice', 'turkey', 'ice cream',
#        'sliced cheese', 'canned fruit', 'popcorn', 'baking powder',
#        'kitchen towels', 'specialty vegetables', 'cake bar',
#        'specialty bar', 'flour', 'softener', 'cleaner', 'soap', 'vinegar',
#        'roll products ', 'pudding powder', 'pet care', 'whisky',
#        'zwieback', 'sparkling wine', 'dog food', 'liquor', 'photo/film',
#        'jam', 'chocolate marshmallow', 'curd cheese', 'spread cheese',
#        'Instant food products', 'sweet spreads', 'brandy', 'canned fish',
#        'baby cosmetics', 'frozen potato products', 'ketchup',
#        'cooking chocolate', 'hair spray', 'honey', 'light bulbs',
#        'specialty fat', 'cream', 'flower soil/fertilizer', 'ready soups',
#        'tea', 'salad dressing', 'cookware', 'toilet cleaner',
#        'meat spreads', 'potato products', 'detergent', 'liqueur',
#        'decalcifier', 'cocoa drinks', 'tidbits', 'rum', 'prosecco',
#        'organic products', 'syrup', 'organic sausage',
#        'house keeping products', 'frozen fruits', 'bathroom cleaner',
#        'skin care', 'bags', 'rubbing alcohol', 'make up remover',
#        'preservation products', 'kitchen utensil'], dtype=object)

# %%
# preprocess itemdescription

# to lower string
train_data["itemDescription"] = train_data["itemDescription"].str.lower()

# remove special characters/punctuation
train_data["itemDescription"] = train_data["itemDescription"].str.replace(r'[^\w\s]+', '', regex=True)

train_data['itemDescription'].unique()
# Out:
# array(['frankfurter', 'pork', 'root vegetables', 'onions', 'waffles',
#        'cereals', 'yogurt', 'sausage', 'rollsbuns', 'chocolate',
#        'whippedsour cream', 'butter', 'curd', 'frozen meals',
#        'whole milk', 'tropical fruit', 'sugar', 'specialty cheese',
#        'other vegetables', 'fruitvegetable juice', 'misc beverages',
#        'frozen vegetables', 'spices', 'coffee', 'cream cheese ',
#        'redblush wine', 'dessert', 'long life bakery product',
#        'domestic eggs', 'abrasive cleaner', 'berries', 'liquor appetizer',
#        'semifinished bread', 'newspapers', 'beverages', 'beef',
#        'female sanitary products', 'salt', 'soda', 'sauces', 'oil',
#        'snack products', 'brown bread', 'hygiene articles',
#        'artif sweetener', 'bottled beer', 'canned beer', 'hamburger meat',
#        'liver loaf', 'soups', 'pip fruit', 'hard cheese', 'shopping bags',
#        'canned vegetables', 'napkins', 'citrus fruit', 'margarine',
#        'pasta', 'salty snack', 'candles', 'cat food', 'meat', 'candy',
#        'condensed milk', 'uhtmilk', 'chewing gum', 'chicken',
#        'soft cheese', 'pastry', 'specialty chocolate',
#        'packaged fruitvegetables', 'bottled water', 'cling filmbags',
#        'processed cheese', 'mustard', 'seasonal products', 'ham', 'herbs',
#        'white bread', 'mayonnaise', 'dental care', 'grapes', 'fish',
#        'nut snack', 'pickled vegetables', 'butter milk',
#        'finished products', 'dishes', 'frozen fish', 'dish cleaner',
#        'frozen dessert', 'flower seeds', 'male cosmetics', 'white wine',
#        'frozen chicken', 'instant coffee', 'pot plants', 'nutsprunes',
#        'rice', 'turkey', 'ice cream', 'sliced cheese', 'canned fruit',
#        'popcorn', 'baking powder', 'kitchen towels',
#        'specialty vegetables', 'cake bar', 'specialty bar', 'flour',
#        'softener', 'cleaner', 'soap', 'vinegar', 'roll products ',
#        'pudding powder', 'pet care', 'whisky', 'zwieback',
#        'sparkling wine', 'dog food', 'liquor', 'photofilm', 'jam',
#        'chocolate marshmallow', 'curd cheese', 'spread cheese',
#        'instant food products', 'sweet spreads', 'brandy', 'canned fish',
#        'baby cosmetics', 'frozen potato products', 'ketchup',
#        'cooking chocolate', 'hair spray', 'honey', 'light bulbs',
#        'specialty fat', 'cream', 'flower soilfertilizer', 'ready soups',
#        'tea', 'salad dressing', 'cookware', 'toilet cleaner',
#        'meat spreads', 'potato products', 'detergent', 'liqueur',
#        'decalcifier', 'cocoa drinks', 'tidbits', 'rum', 'prosecco',
#        'organic products', 'syrup', 'organic sausage',
#        'house keeping products', 'frozen fruits', 'bathroom cleaner',
#        'skin care', 'bags', 'rubbing alcohol', 'make up remover',
#        'preservation products', 'kitchen utensil'], dtype=object)

# %%
# convert date to datestamp
train_data['Date'] = pd.to_datetime(train_data['Date'], format="%d/%m/%Y")
train_data
# Out:
#        Member_number       Date  itemDescription  year  month  day  \
# 0               3021 2015-01-30      frankfurter  2015      1   30
# 1               1292 2015-10-24             pork  2015     10   24
# 2               4206 2014-04-04  root vegetables  2014      4    4
# 3               4369 2015-08-25           onions  2015      8   25
# 4               1522 2014-07-01          waffles  2014      7    1
# ...              ...        ...              ...   ...    ...  ...
# 26995           4206 2014-01-14        rollsbuns  2014      1   14
# 26996           1660 2014-06-15    domestic eggs  2014      6   15
# 26997           1595 2015-05-10       liver loaf  2015      5   10
# 26998           3231 2015-03-31          sausage  2015      3   31
# 26999           2550 2014-12-07      canned beer  2014     12    7
#
#        day_of_week
# 0                4
# 1                5
# 2                4
# 3                1
# 4                1
# ...            ...
# 26995            1
# 26996            6
# 26997            6
# 26998            1
# 26999            6
#
# [27000 rows x 7 columns]

# %% [markdown]
# The dataset presents the item purchases of each member from 01/01/2014 to 30/12/2015.
#
# For effective pattern mining, it is recommended to aggregate the list of items purchased by each member into quarterly periods each year. The reasons behind are [1]:
#
# * Captures seasonal variations and holiday impacts on consumer behavior
#
# * Aligns with business quarters for effective strategic reviews and planning of storing products

# %%
# extract year and date to quarter
train_data['Year'] = train_data['Date'].dt.year
train_data['Quarter'] = train_data['Date'].dt.to_period('Q')

# %%
# group data within 1 transaction based on member number, year, and quarter
grouped = train_data.groupby(['Member_number', 'Year', 'Quarter'])['itemDescription'].apply(list).reset_index()
grouped
# Out:
#        Member_number  Year Quarter                 itemDescription
# 0               1000  2014  2014Q2                        [pastry]
# 1               1000  2015  2015Q1               [sausage, yogurt]
# 2               1000  2015  2015Q2      [soda, pickled vegetables]
# 3               1000  2015  2015Q3   [misc beverages, canned beer]
# 4               1000  2015  2015Q4                       [sausage]
# ...              ...   ...     ...                             ...
# 11307           4999  2015  2015Q2                   [butter milk]
# 11308           4999  2015  2015Q4          [herbs, bottled water]
# 11309           5000  2014  2014Q3  [onions, fruitvegetable juice]
# 11310           5000  2014  2014Q4              [other vegetables]
# 11311           5000  2015  2015Q4                          [soda]
#
# [11312 rows x 4 columns]

# %%
# extract item lists for the FP-Growth input
transactions = grouped['itemDescription'].tolist()
transactions
# Out:
# [['pastry'],
#  ['sausage', 'yogurt'],
#  ['soda', 'pickled vegetables'],
#  ['misc beverages', 'canned beer'],
#  ['sausage'],
#  ['rollsbuns', 'whole milk', 'sausage'],
#  ['soda', 'whole milk'],
#  ['frankfurter', 'soda', 'whippedsour cream', 'curd'],
#  ['white bread', 'beef'],
#  ['whole milk', 'butter'],
#  ['frozen vegetables'],
#  ['sugar', 'tropical fruit'],
#  ['butter milk'],
#  ['dental care', 'rollsbuns'],
#  ['root vegetables', 'detergent'],
#  ['sausage'],
#  ['canned beer', 'cling filmbags', 'dish cleaner', 'frozen fish'],
#  ['pip fruit', 'whole milk'],
#  ['whole milk', 'pastry'],
#  ['shopping bags', 'chocolate', 'redblush wine', 'whole milk', 'rollsbuns'],
#  ['other vegetables', 'hygiene articles'],
#  ['whippedsour cream', 'margarine'],
#  ['rollsbuns', 'rollsbuns'],
#  ['softener'],
#  ['rice'],
#  ['shopping bags'],
#  ['chicken',
#   'bottled beer',
#   'frankfurter',
#   'rollsbuns',
#   'chocolate',
#   'frankfurter',
#   'flour'],
#  ['dessert', 'hamburger meat', 'liver loaf'],
#  ['photofilm', 'tropical fruit', 'white wine', 'domestic eggs', 'yogurt'],
#  ['canned fish', 'cocoa drinks'],
#  ['yogurt', 'tropical fruit', 'herbs'],
#  ['pastry'],
#  ['coffee', 'uhtmilk', 'pip fruit'],
#  ['bottled water', 'specialty bar', 'bottled water'],
#  ['kitchen towels', 'sliced cheese'],
#  ['pip fruit'],
#  ['curd cheese',
#   'bottled water',
#   'pastry',
#   'rollsbuns',
#   'citrus fruit',
#   'candy'],
#  ['whole milk',
#   'other vegetables',
#   'grapes',
#   'candles',
#   'herbs',
#   'frankfurter'],
#  ['frozen vegetables', 'brown bread'],
#  ['processed cheese', 'frankfurter', 'yogurt', 'whole milk'],
#  ['rollsbuns', 'onions', 'shopping bags', 'tropical fruit'],
#  ['whole milk', 'frozen vegetables', 'bottled water', 'candy'],
#  ['other vegetables', 'mustard'],
#  ['root vegetables', 'mayonnaise'],
#  ['domestic eggs', 'frozen meals', 'meat'],
#  ['butter milk'],
#  ['whole milk', 'bottled beer', 'yogurt', 'sausage'],
#  ['cookware'],
#  ['chocolate', 'fruitvegetable juice'],
#  ['beef'],
#  ['whole milk'],
#  ['soft cheese', 'pip fruit', 'bottled beer'],
#  ['mayonnaise', 'pip fruit', 'frankfurter', 'redblush wine', 'rollsbuns'],
#  ['other vegetables', 'root vegetables'],
#  ['beef'],
#  ['brown bread', 'pet care'],
#  ['other vegetables', 'rollsbuns'],
#  ['dessert'],
#  ['curd', 'long life bakery product'],
#  ['domestic eggs', 'cake bar', 'beverages'],
#  ['root vegetables'],
#  ['hamburger meat'],
#  ['yogurt', 'frozen meals', 'newspapers', 'butter'],
#  ['shopping bags', 'canned beer'],
#  ['canned beer', 'frozen fish', 'rollsbuns', 'spices'],
#  ['butter', 'sliced cheese'],
#  ['rollsbuns', 'baking powder'],
#  ['curd', 'tropical fruit', 'liquor', 'yogurt'],
#  ['napkins', 'whippedsour cream', 'beef'],
#  ['fruitvegetable juice', 'sausage'],
#  ['domestic eggs', 'male cosmetics', 'chicken'],
#  ['specialty bar', 'sausage'],
#  ['white bread',
#   'bottled beer',
#   'root vegetables',
#   'yogurt',
#   'rollsbuns',
#   'packaged fruitvegetables',
#   'whippedsour cream'],
#  ['root vegetables', 'other vegetables', 'fish', 'tropical fruit'],
#  ['coffee', 'shopping bags'],
#  ['cream cheese ', 'ham'],
#  ['canned beer', 'uhtmilk'],
#  ['long life bakery product', 'root vegetables'],
#  ['dessert', 'sausage', 'citrus fruit', 'pickled vegetables'],
#  ['candy', 'dental care', 'butter', 'salty snack', 'fruitvegetable juice'],
#  ['root vegetables', 'root vegetables'],
#  ['whole milk', 'salt'],
#  ['bottled water'],
#  ['redblush wine', 'rollsbuns'],
#  ['hamburger meat', 'pork'],
#  ['sugar', 'bottled water', 'baking powder', 'rollsbuns', 'rollsbuns'],
#  ['soda', 'butter'],
#  ['canned beer', 'flower seeds', 'onions'],
#  ['specialty chocolate', 'root vegetables'],
#  ['ham', 'dessert'],
#  ['ice cream', 'pot plants'],
#  ['beverages', 'cream cheese '],
#  ['other vegetables'],
#  ['whippedsour cream', 'newspapers'],
#  ['shopping bags', 'pastry', 'white bread'],
#  ['other vegetables', 'soda', 'butter', 'white bread', 'berries'],
#  ['root vegetables', 'yogurt'],
#  ['frankfurter', 'pastry'],
#  ['dessert', 'snack products', 'sausage'],
#  ['chicken', 'soda', 'waffles', 'rollsbuns'],
#  ['bottled water', 'domestic eggs', 'tropical fruit'],
#  ['whole milk'],
#  ['pip fruit', 'salt'],
#  ['yogurt', 'whole milk', 'rollsbuns', 'yogurt'],
#  ['newspapers', 'whole milk'],
#  ['vinegar'],
#  ['rollsbuns', 'white bread', 'tropical fruit'],
#  ['shopping bags', 'citrus fruit', 'cake bar'],
#  ['canned beer'],
#  ['margarine', 'napkins'],
#  ['pip fruit',
#   'whole milk',
#   'sausage',
#   'fruitvegetable juice',
#   'pork',
#   'whippedsour cream',
#   'whole milk',
#   'butter'],
#  ['frozen meals', 'pip fruit', 'herbs'],
#  ['whippedsour cream',
#   'specialty chocolate',
#   'butter',
#   'other vegetables',
#   'instant food products'],
#  ['salty snack', 'rollsbuns'],
#  ['rollsbuns', 'whole milk'],
#  ['yogurt'],
#  ['chicken', 'packaged fruitvegetables', 'onions'],
#  ['frozen vegetables', 'brown bread'],
#  ['dessert', 'prosecco'],
#  ['hamburger meat', 'yogurt'],
#  ['citrus fruit', 'bottled water'],
#  ['beef'],
#  ['tropical fruit', 'sliced cheese'],
#  ['chocolate marshmallow', 'napkins'],
#  ['citrus fruit', 'rollsbuns'],
#  ['other vegetables'],
#  ['curd', 'root vegetables'],
#  ['root vegetables',
#   'butter',
#   'fruitvegetable juice',
#   'yogurt',
#   'specialty chocolate'],
#  ['chicken'],
#  ['pastry', 'pork', 'bottled water'],
#  ['soda', 'pip fruit'],
#  ['soda', 'curd'],
#  ['sweet spreads'],
#  ['rollsbuns', 'whole milk', 'condensed milk', 'soda'],
#  ['rollsbuns'],
#  ['margarine'],
#  ['butter'],
#  ['frankfurter', 'candy', 'white bread'],
#  ['pasta', 'yogurt', 'yogurt', 'cat food'],
#  ['dishes',
#   'hygiene articles',
#   'other vegetables',
#   'whippedsour cream',
#   'uhtmilk'],
#  ['meat', 'whole milk'],
#  ['hamburger meat'],
#  ['coffee', 'frozen vegetables'],
#  ['shopping bags', 'shopping bags'],
#  ['tropical fruit',
#   'popcorn',
#   'other vegetables',
#   'female sanitary products',
#   'rollsbuns',
#   'soda',
#   'dishes',
#   'other vegetables',
#   'tropical fruit',
#   'hamburger meat',
#   'redblush wine',
#   'cream cheese ',
#   'fish'],
#  ['beverages', 'chicken', 'coffee'],
#  ['soda', 'hamburger meat', 'shopping bags'],
#  ['dog food'],
#  ['whole milk', 'soda'],
#  ['frankfurter', 'margarine', 'whippedsour cream', 'butter milk', 'yogurt'],
#  ['soft cheese', 'other vegetables'],
#  ['chicken',
#   'waffles',
#   'rollsbuns',
#   'frozen vegetables',
#   'whole milk',
#   'sugar',
#   'soda'],
#  ['other vegetables'],
#  ['pastry'],
#  ['soda'],
#  ['oil'],
#  ['margarine', 'citrus fruit'],
#  ['pork'],
#  ['bottled water', 'soda', 'yogurt'],
#  ['ham', 'whole milk'],
#  ['meat spreads', 'pip fruit', 'other vegetables'],
#  ['salty snack', 'sliced cheese', 'domestic eggs'],
#  ['tropical fruit', 'uhtmilk'],
#  ['root vegetables'],
#  ['sausage'],
#  ['cling filmbags', 'salty snack', 'sausage'],
#  ['dessert'],
#  ['soda'],
#  ['beef'],
#  ['whippedsour cream', 'hard cheese'],
#  ['beverages', 'dessert'],
#  ['margarine',
#   'tropical fruit',
#   'whole milk',
#   'root vegetables',
#   'instant food products'],
#  ['whole milk'],
#  ['frozen fruits', 'ham', 'ketchup', 'white bread', 'whippedsour cream'],
#  ['long life bakery product', 'whole milk'],
#  ['yogurt', 'shopping bags', 'whole milk', 'butter'],
#  ['citrus fruit'],
#  ['rollsbuns', 'candy'],
#  ['root vegetables', 'whole milk'],
#  ['rollsbuns', 'cream cheese '],
#  ['long life bakery product', 'root vegetables'],
#  ['long life bakery product', 'soda', 'whole milk', 'hamburger meat', 'rum'],
#  ['beef', 'frankfurter', 'dessert'],
#  ['root vegetables', 'bottled beer'],
#  ['whole milk', 'other vegetables'],
#  ['oil'],
#  ['tropical fruit'],
#  ['hamburger meat', 'rollsbuns', 'coffee', 'tropical fruit'],
#  ['soda'],
#  ['spread cheese'],
#  ['rollsbuns', 'pork'],
#  ['brown bread', 'fruitvegetable juice'],
#  ['tropical fruit', 'bottled beer', 'dishes'],
#  ['cream cheese ', 'newspapers'],
#  ['redblush wine'],
#  ['roll products ', 'yogurt'],
#  ['ham', 'other vegetables'],
#  ['canned beer', 'frankfurter'],
#  ['brown bread'],
#  ['domestic eggs', 'yogurt'],
#  ['brown bread'],
#  ['prosecco', 'pip fruit', 'curd'],
#  ['detergent'],
#  ['oil', 'shopping bags'],
#  ['instant coffee', 'misc beverages'],
#  ['fruitvegetable juice'],
#  ['uhtmilk', 'canned fish'],
#  ['pip fruit'],
#  ['frozen meals'],
#  ['fruitvegetable juice', 'frankfurter', 'bottled water', 'citrus fruit'],
#  ['brown bread'],
#  ['frankfurter', 'chicken'],
#  ['whole milk', 'bottled water', 'ham', 'butter'],
#  ['pastry',
#   'rollsbuns',
#   'soda',
#   'brown bread',
#   'butter',
#   'artif sweetener',
#   'white bread'],
#  ['root vegetables'],
#  ['tropical fruit', 'soda'],
#  ['soda', 'chicken'],
#  ['coffee', 'rollsbuns', 'white bread'],
#  ['bottled water', 'redblush wine', 'sweet spreads'],
#  ['onions', 'napkins'],
#  ['soda'],
#  ['root vegetables', 'frozen vegetables', 'pet care'],
#  ['yogurt', 'beverages'],
#  ['bottled beer'],
#  ['pastry',
#   'whole milk',
#   'butter milk',
#   'coffee',
#   'frankfurter',
#   'newspapers'],
#  ['hygiene articles'],
#  ['beef', 'other vegetables'],
#  ['soda', 'specialty chocolate'],
#  ['hamburger meat', 'whole milk'],
#  ['sliced cheese'],
#  ['other vegetables'],
#  ['newspapers', 'yogurt', 'soda'],
#  ['citrus fruit'],
#  ['herbs', 'margarine', 'soda', 'rollsbuns'],
#  ['whippedsour cream', 'ice cream'],
#  ['rollsbuns', 'soda', 'butter', 'citrus fruit', 'other vegetables', 'beef'],
#  ['whole milk', 'white bread', 'specialty chocolate'],
#  ['other vegetables'],
#  ['soda', 'berries', 'ham', 'flower seeds', 'white bread', 'coffee'],
#  ['chocolate', 'sausage'],
#  ['pot plants'],
#  ['berries'],
#  ['hard cheese', 'whole milk'],
#  ['domestic eggs', 'meat', 'baking powder'],
#  ['yogurt'],
#  ['yogurt'],
#  ['dishes', 'specialty chocolate', 'napkins', 'pastry', 'detergent', 'yogurt'],
#  ['whole milk', 'ice cream'],
#  ['yogurt'],
#  ['photofilm', 'shopping bags'],
#  ['specialty bar', 'soda'],
#  ['bottled beer',
#   'salty snack',
#   'grapes',
#   'instant food products',
#   'domestic eggs',
#   'sausage',
#   'other vegetables',
#   'frankfurter',
#   'bottled water',
#   'bottled beer'],
#  ['dessert'],
#  ['newspapers', 'whole milk', 'salty snack', 'pasta', 'chocolate marshmallow'],
#  ['whole milk', 'brown bread', 'hamburger meat'],
#  ['soda'],
#  ['sausage', 'sausage', 'root vegetables', 'tropical fruit', 'misc beverages'],
#  ['shopping bags'],
#  ['pickled vegetables'],
#  ['domestic eggs'],
#  ['cake bar', 'sausage'],
#  ['whippedsour cream', 'shopping bags', 'whole milk', 'curd'],
#  ['soda'],
#  ['bottled water', 'whippedsour cream'],
#  ['citrus fruit', 'dessert'],
#  ['tropical fruit', 'candy'],
#  ['shopping bags', 'rollsbuns', 'cat food'],
#  ['canned beer',
#   'citrus fruit',
#   'yogurt',
#   'specialty chocolate',
#   'hard cheese'],
#  ['frozen vegetables',
#   'bottled water',
#   'root vegetables',
#   'rollsbuns',
#   'cat food'],
#  ['other vegetables'],
#  ['pip fruit', 'brown bread', 'instant coffee', 'root vegetables'],
#  ['pork', 'spread cheese'],
#  ['hamburger meat'],
#  ['whole milk', 'yogurt'],
#  ['soda', 'grapes', 'butter'],
#  ['whippedsour cream', 'sparkling wine', 'rollsbuns', 'brown bread'],
#  ['root vegetables', 'frozen vegetables'],
#  ['white wine'],
#  ['brown bread', 'beverages'],
#  ['white bread', 'detergent', 'other vegetables'],
#  ['candles', 'chicken', 'pastry'],
#  ['waffles', 'tea', 'hygiene articles'],
#  ['cream', 'herbs', 'yogurt'],
#  ['root vegetables'],
#  ['domestic eggs'],
#  ['yogurt', 'rollsbuns', 'other vegetables', 'herbs'],
#  ['whole milk', 'pork'],
#  ['white bread', 'other vegetables'],
#  ['bottled water', 'tropical fruit', 'whole milk'],
#  ['beef', 'onions', 'newspapers'],
#  ['rollsbuns', 'whole milk', 'shopping bags'],
#  ['liver loaf', 'rollsbuns', 'chicken', 'misc beverages', 'spread cheese'],
#  ['misc beverages'],
#  ['frozen potato products', 'pastry', 'grapes', 'whippedsour cream'],
#  ['salty snack'],
#  ['brown bread', 'shopping bags'],
#  ['chocolate', 'whole milk'],
#  ['pip fruit', 'pastry', 'sugar', 'margarine', 'pip fruit', 'salty snack'],
#  ['margarine', 'citrus fruit'],
#  ['margarine', 'yogurt'],
#  ['pickled vegetables'],
#  ['soda'],
#  ['yogurt', 'ham'],
#  ['dishes', 'soda', 'butter', 'curd', 'whole milk'],
#  ['soda', 'frozen vegetables', 'whole milk'],
#  ['sugar', 'flour', 'bottled water'],
#  ['beef', 'semifinished bread'],
#  ['dish cleaner', 'ice cream'],
#  ['canned beer'],
#  ['newspapers', 'yogurt'],
#  ['pudding powder', 'pork'],
#  ['baking powder', 'bottled beer', 'specialty bar'],
#  ['chocolate', 'shopping bags', 'brown bread'],
#  ['chicken', 'shopping bags'],
#  ['shopping bags', 'uhtmilk', 'dog food', 'sausage'],
#  ['other vegetables'],
#  ['turkey', 'root vegetables', 'yogurt'],
#  ['yogurt'],
#  ['napkins',
#   'canned vegetables',
#   'butter milk',
#   'other vegetables',
#   'brown bread',
#   'soda'],
#  ['other vegetables', 'zwieback'],
#  ['newspapers', 'root vegetables', 'hard cheese'],
#  ['rollsbuns', 'beverages', 'newspapers'],
#  ['rollsbuns', 'frankfurter'],
#  ['meat'],
#  ['bottled beer', 'sliced cheese', 'frozen vegetables'],
#  ['canned beer', 'pip fruit', 'processed cheese'],
#  ['rollsbuns', 'house keeping products', 'curd', 'pickled vegetables'],
#  ['yogurt', 'ham'],
#  ['pastry', 'hair spray', 'butter'],
#  ['whole milk', 'grapes'],
#  ['tropical fruit', 'sugar'],
#  ['white bread', 'uhtmilk'],
#  ['other vegetables',
#   'brown bread',
#   'tropical fruit',
#   'meat',
#   'rice',
#   'condensed milk',
#   'pastry'],
#  ['specialty bar'],
#  ['coffee', 'shopping bags'],
#  ['frozen vegetables'],
#  ['bottled water', 'citrus fruit'],
#  ['yogurt', 'oil', 'rollsbuns'],
#  ['pip fruit', 'whole milk'],
#  ['rollsbuns', 'cling filmbags'],
#  ['soda', 'pork'],
#  ['bottled beer', 'hygiene articles'],
#  ['soda', 'yogurt'],
#  ['root vegetables', 'rollsbuns'],
#  ['rollsbuns', 'margarine'],
#  ['pastry'],
#  ['popcorn', 'shopping bags', 'condensed milk', 'citrus fruit'],
#  ['whippedsour cream'],
#  ['root vegetables', 'misc beverages', 'pork'],
#  ['roll products ', 'citrus fruit', 'soda', 'soda'],
#  ['margarine', 'rollsbuns'],
#  ['butter', 'uhtmilk', 'other vegetables'],
#  ['frozen vegetables', 'soda', 'specialty bar'],
#  ['domestic eggs', 'liquor'],
#  ['white bread'],
#  ['coffee', 'meat'],
#  ['baking powder', 'whole milk'],
#  ['white wine', 'flower seeds'],
#  ['cream cheese ', 'flower seeds', 'grapes', 'frozen meals', 'yogurt'],
#  ['soda'],
#  ['yogurt'],
#  ['cream cheese ', 'tropical fruit'],
#  ['bottled water', 'dessert', 'frankfurter'],
#  ['bottled beer', 'whole milk'],
#  ['other vegetables',
#   'other vegetables',
#   'rollsbuns',
#   'shopping bags',
#   'salty snack'],
#  ['whole milk'],
#  ['shopping bags', 'shopping bags', 'coffee', 'pastry'],
#  ['domestic eggs', 'pork', 'rice', 'curd', 'rollsbuns', 'napkins'],
#  ['cream cheese '],
#  ['oil'],
#  ['yogurt', 'brown bread', 'pastry'],
#  ['butter', 'hard cheese'],
#  ['dessert', 'butter', 'shopping bags', 'sausage', 'soda', 'soda'],
#  ['flower seeds', 'citrus fruit'],
#  ['shopping bags', 'rollsbuns'],
#  ['tropical fruit', 'root vegetables'],
#  ['butter milk', 'whole milk', 'brown bread'],
#  ['herbs', 'citrus fruit'],
#  ['beef'],
#  ['canned beer', 'nut snack'],
#  ['other vegetables', 'sugar', 'whole milk', 'other vegetables'],
#  ['napkins'],
#  ['butter milk', 'root vegetables', 'rollsbuns'],
#  ['soft cheese', 'rollsbuns', 'brown bread'],
#  ['pickled vegetables', 'pork'],
#  ['other vegetables', 'frankfurter', 'waffles', 'photofilm', 'curd'],
#  ['pip fruit', 'other vegetables'],
#  ['whole milk', 'rollsbuns'],
#  ['yogurt', 'cat food'],
#  ['white bread'],
#  ['newspapers'],
#  ['soda', 'other vegetables', 'rollsbuns', 'napkins'],
#  ['uhtmilk', 'soda'],
#  ['oil', 'pork', 'pickled vegetables'],
#  ['spread cheese', 'misc beverages'],
#  ['whole milk', 'sugar', 'whole milk'],
#  ['pork', 'root vegetables', 'domestic eggs'],
#  ['chicken', 'whippedsour cream', 'white bread', 'whole milk'],
#  ['fish', 'canned beer'],
#  ['root vegetables', 'hard cheese'],
#  ['other vegetables', 'brown bread'],
#  ['root vegetables'],
#  ['frozen vegetables',
#   'soft cheese',
#   'cereals',
#   'sliced cheese',
#   'root vegetables',
#   'berries',
#   'candy',
#   'curd'],
#  ['soda', 'yogurt', 'yogurt'],
#  ['bottled water', 'shopping bags', 'waffles'],
#  ['pork', 'whole milk', 'margarine', 'bottled beer'],
#  ['soda'],
#  ['frozen meals'],
#  ['specialty chocolate', 'canned fish'],
#  ['soda'],
#  ['pork'],
#  ['whole milk',
#   'shopping bags',
#   'white bread',
#   'sausage',
#   'sliced cheese',
#   'yogurt'],
#  ['tropical fruit', 'soda', 'other vegetables'],
#  ['bottled beer', 'yogurt'],
#  ['frozen vegetables', 'yogurt', 'seasonal products'],
#  ['uhtmilk', 'rollsbuns', 'bottled water'],
#  ['pip fruit'],
#  ['sugar', 'fruitvegetable juice', 'other vegetables'],
#  ['curd', 'soft cheese'],
#  ['pip fruit'],
#  ['frozen meals', 'soda'],
#  ['domestic eggs'],
#  ['dish cleaner', 'canned beer'],
#  ['chicken'],
#  ['chewing gum', 'bottled beer', 'ready soups'],
#  ['grapes'],
#  ['frankfurter', 'mustard'],
#  ['female sanitary products'],
#  ['root vegetables',
#   'whole milk',
#   'citrus fruit',
#   'canned beer',
#   'other vegetables',
#   'frozen vegetables'],
#  ['sausage', 'yogurt', 'pet care', 'whole milk'],
#  ['berries', 'other vegetables'],
#  ['curd', 'beef', 'frozen meals'],
#  ['tropical fruit', 'uhtmilk'],
#  ['yogurt'],
#  ['cream cheese ', 'whole milk'],
#  ['rollsbuns', 'other vegetables', 'rollsbuns', 'butter', 'root vegetables'],
#  ['light bulbs', 'citrus fruit'],
#  ['frozen vegetables', 'domestic eggs'],
#  ['whole milk', 'whole milk', 'yogurt', 'root vegetables'],
#  ['frozen meals', 'shopping bags'],
#  ['chewing gum'],
#  ['bottled beer', 'coffee'],
#  ['mustard', 'tropical fruit'],
#  ['beef', 'newspapers'],
#  ['yogurt', 'spread cheese', 'other vegetables'],
#  ['berries', 'male cosmetics', 'canned beer'],
#  ['misc beverages'],
#  ['bottled water'],
#  ['beef', 'citrus fruit'],
#  ['root vegetables', 'sliced cheese', 'canned vegetables'],
#  ['frozen vegetables'],
#  ['chocolate', 'packaged fruitvegetables', 'pork'],
#  ['spices', 'curd'],
#  ['root vegetables', 'brown bread', 'bottled water', 'tropical fruit'],
#  ['rollsbuns', 'other vegetables'],
#  ['coffee', 'domestic eggs'],
#  ['sweet spreads'],
#  ['frankfurter', 'frozen vegetables'],
#  ['whole milk', 'chocolate', 'bottled beer'],
#  ['margarine', 'soda', 'other vegetables', 'whole milk', 'white bread'],
#  ['cleaner',
#   'napkins',
#   'bottled water',
#   'finished products',
#   'napkins',
#   'napkins'],
#  ['cake bar', 'bottled beer'],
#  ['shopping bags'],
#  ['whole milk', 'canned beer'],
#  ['chicken', 'pip fruit'],
#  ['whippedsour cream'],
#  ['pork',
#   'dog food',
#   'rollsbuns',
#   'bottled water',
#   'bottled water',
#   'soda',
#   'whole milk'],
#  ['whippedsour cream', 'soda'],
#  ['pasta', 'brown bread', 'soda', 'other vegetables'],
#  ['beverages', 'specialty chocolate'],
#  ['bottled water'],
#  ['rollsbuns', 'margarine'],
#  ['specialty bar'],
#  ['rollsbuns', 'bottled beer', 'fruitvegetable juice'],
#  ['hard cheese', 'rollsbuns'],
#  ['syrup'],
#  ['root vegetables', 'baking powder', 'pickled vegetables'],
#  ['whippedsour cream'],
#  ['fruitvegetable juice'],
#  ['other vegetables'],
#  ['brown bread', 'citrus fruit', 'specialty chocolate'],
#  ['beef', 'chocolate', 'yogurt', 'butter'],
#  ['shopping bags', 'whole milk', 'soda', 'white wine', 'yogurt'],
#  ['hard cheese', 'sugar', 'bottled water', 'soda'],
#  ['domestic eggs'],
#  ['tropical fruit'],
#  ['other vegetables'],
#  ['canned beer', 'brown bread', 'rollsbuns'],
#  ['tropical fruit'],
#  ['oil'],
#  ['salt', 'ice cream', 'other vegetables'],
#  ['bottled water', 'jam'],
#  ['soda', 'cereals'],
#  ['frozen meals', 'napkins'],
#  ['frozen potato products', 'whole milk'],
#  ['citrus fruit', 'white bread'],
#  ['oil', 'dishes'],
#  ['white bread'],
#  ['sausage', 'root vegetables'],
#  ['mustard'],
#  ['redblush wine'],
#  ['baking powder', 'candy', 'canned fish'],
#  ['ice cream', 'beef', 'shopping bags'],
#  ['hamburger meat', 'pip fruit'],
#  ['domestic eggs', 'sausage', 'ham', 'root vegetables', 'spread cheese'],
#  ['brown bread',
#   'other vegetables',
#   'dessert',
#   'sausage',
#   'canned beer',
#   'cream cheese '],
#  ['newspapers'],
#  ['root vegetables', 'sweet spreads'],
#  ['frankfurter',
#   'frozen meals',
#   'ice cream',
#   'chewing gum',
#   'canned beer',
#   'beef'],
#  ['pip fruit', 'chocolate'],
#  ['domestic eggs'],
#  ['butter', 'soda'],
#  ['canned fruit', 'other vegetables'],
#  ['soda', 'domestic eggs'],
#  ['onions', 'shopping bags'],
#  ['bottled water', 'cleaner', 'butter milk'],
#  ['bottled beer', 'other vegetables'],
#  ['rollsbuns', 'whole milk'],
#  ['tropical fruit'],
#  ['sliced cheese', 'bottled beer'],
#  ['pip fruit', 'soda', 'bottled water', 'bottled beer', 'rollsbuns'],
#  ['specialty chocolate',
#   'other vegetables',
#   'root vegetables',
#   'canned beer',
#   'meat spreads'],
#  ['root vegetables', 'sparkling wine', 'root vegetables'],
#  ['berries', 'white bread'],
#  ['specialty chocolate', 'hamburger meat', 'citrus fruit', 'other vegetables'],
#  ['brown bread', 'pastry'],
#  ['fruitvegetable juice', 'butter'],
#  ['shopping bags', 'soda'],
#  ['root vegetables', 'citrus fruit'],
#  ['pip fruit', 'whole milk', 'napkins'],
#  ['pastry', 'butter', 'coffee'],
#  ['shopping bags', 'butter'],
#  ['finished products', 'liquor'],
#  ['soft cheese', 'whole milk'],
#  ['pip fruit', 'shopping bags'],
#  ['newspapers'],
#  ['bottled beer', 'mayonnaise', 'rollsbuns'],
#  ['whole milk', 'brown bread'],
#  ['whippedsour cream'],
#  ['sausage'],
#  ['citrus fruit'],
#  ['root vegetables',
#   'packaged fruitvegetables',
#   'whippedsour cream',
#   'root vegetables'],
#  ['citrus fruit', 'napkins'],
#  ['specialty chocolate', 'frozen fish'],
#  ['newspapers', 'other vegetables'],
#  ['rollsbuns', 'grapes'],
#  ['beverages', 'sausage'],
#  ['salty snack', 'bottled water', 'sugar', 'rollsbuns'],
#  ['detergent', 'brown bread'],
#  ['citrus fruit', 'root vegetables', 'canned fish', 'rollsbuns'],
#  ['misc beverages', 'whole milk'],
#  ['coffee', 'oil'],
#  ['yogurt'],
#  ['yogurt'],
#  ['root vegetables', 'curd cheese', 'soda', 'semifinished bread'],
#  ['rollsbuns', 'yogurt', 'whole milk', 'beverages'],
#  ['softener', 'chocolate'],
#  ['sliced cheese', 'pip fruit'],
#  ['grapes', 'root vegetables'],
#  ['oil', 'whole milk'],
#  ['bottled water', 'ready soups'],
#  ['yogurt', 'yogurt', 'chewing gum', 'whole milk'],
#  ['hygiene articles'],
#  ['cat food', 'sausage'],
#  ['soda', 'sugar', 'soda', 'softener', 'other vegetables', 'sausage'],
#  ['shopping bags', 'pickled vegetables', 'ham'],
#  ['semifinished bread', 'whole milk', 'yogurt'],
#  ['bottled water'],
#  ['yogurt'],
#  ['misc beverages', 'shopping bags'],
#  ['tropical fruit', 'butter milk'],
#  ['dessert'],
#  ['yogurt', 'shopping bags'],
#  ['brown bread'],
#  ['fruitvegetable juice', 'specialty cheese'],
#  ['margarine', 'butter'],
#  ['specialty bar'],
#  ['other vegetables',
#   'specialty bar',
#   'tropical fruit',
#   'uhtmilk',
#   'salty snack',
#   'rollsbuns'],
#  ['specialty bar'],
#  ['salt'],
#  ['beef', 'domestic eggs'],
#  ['tropical fruit'],
#  ['other vegetables', 'root vegetables'],
#  ['margarine', 'dessert', 'pork', 'beef', 'newspapers', 'beef', 'brown bread'],
#  ['bottled beer', 'domestic eggs'],
#  ['waffles'],
#  ['meat', 'pip fruit', 'yogurt', 'chicken'],
#  ['sauces', 'yogurt'],
#  ['shopping bags', 'root vegetables'],
#  ['pip fruit', 'other vegetables', 'sliced cheese'],
#  ['long life bakery product', 'citrus fruit'],
#  ['onions', 'turkey'],
#  ['root vegetables',
#   'bottled water',
#   'napkins',
#   'specialty fat',
#   'pastry',
#   'whole milk'],
#  ['bottled water', 'citrus fruit'],
#  ['whole milk', 'sugar'],
#  ['whole milk', 'dog food'],
#  ['cling filmbags', 'curd', 'meat'],
#  ['citrus fruit', 'citrus fruit', 'frozen meals'],
#  ['whole milk', 'fruitvegetable juice', 'whole milk'],
#  ['rollsbuns', 'tropical fruit', 'frozen fish'],
#  ['whole milk', 'candles'],
#  ['canned beer', 'brown bread', 'redblush wine'],
#  ['sausage', 'pasta'],
#  ['margarine', 'chocolate'],
#  ['specialty chocolate',
#   'rice',
#   'napkins',
#   'rollsbuns',
#   'waffles',
#   'butter milk'],
#  ['frankfurter'],
#  ['sugar', 'bottled water'],
#  ['canned beer', 'coffee', 'onions', 'condensed milk'],
#  ['citrus fruit', 'butter', 'uhtmilk'],
#  ['packaged fruitvegetables', 'flour'],
#  ['citrus fruit', 'yogurt', 'semifinished bread'],
#  ['ham'],
#  ['specialty chocolate', 'sausage', 'cooking chocolate'],
#  ['white bread', 'curd', 'jam', 'pastry', 'whole milk', 'rollsbuns'],
#  ['seasonal products', 'soda'],
#  ['other vegetables',
#   'flour',
#   'dessert',
#   'sliced cheese',
#   'whole milk',
#   'whole milk',
#   'bottled beer',
#   'whole milk',
#   'shopping bags',
#   'detergent'],
#  ['brown bread'],
#  ['pastry', 'hard cheese'],
#  ['domestic eggs',
#   'citrus fruit',
#   'beef',
#   'long life bakery product',
#   'vinegar',
#   'specialty bar',
#   'white bread'],
#  ['yogurt'],
#  ['bottled beer', 'beverages'],
#  ['white bread', 'beef', 'frozen potato products'],
#  ['mustard', 'brown bread'],
#  ['newspapers'],
#  ['canned beer', 'sliced cheese'],
#  ['soda'],
#  ['soda', 'butter milk', 'soda'],
#  ['domestic eggs', 'ham'],
#  ['frankfurter', 'misc beverages', 'pastry'],
#  ['hard cheese', 'soda'],
#  ['onions'],
#  ['grapes', 'detergent', 'white wine'],
#  ['sausage', 'pork', 'sliced cheese'],
#  ['pasta'],
#  ['butter', 'bottled water', 'grapes'],
#  ['uhtmilk', 'whippedsour cream', 'shopping bags'],
#  ['canned beer',
#   'soda',
#   'salty snack',
#   'soda',
#   'waffles',
#   'rollsbuns',
#   'margarine',
#   'rollsbuns'],
#  ['other vegetables', 'chicken'],
#  ['bottled water'],
#  ['yogurt'],
#  ['salty snack'],
#  ['soda', 'bottled water'],
#  ['condensed milk',
#   'butter',
#   'abrasive cleaner',
#   'bottled beer',
#   'processed cheese',
#   'roll products ',
#   'curd'],
#  ['spread cheese', 'bottled beer'],
#  ['waffles', 'shopping bags'],
#  ['dishes', 'newspapers', 'pip fruit'],
#  ['cling filmbags', 'whole milk'],
#  ['cleaner', 'misc beverages', 'hard cheese'],
#  ['pork', 'cream cheese ', 'other vegetables'],
#  ['other vegetables', 'beverages', 'citrus fruit'],
#  ['sugar',
#   'rollsbuns',
#   'hard cheese',
#   'tropical fruit',
#   'soda',
#   'whole milk',
#   'ham',
#   'other vegetables'],
#  ['margarine', 'frankfurter'],
#  ['roll products ', 'waffles'],
#  ['soda', 'meat'],
#  ['whippedsour cream', 'processed cheese', 'whole milk', 'yogurt'],
#  ['yogurt',
#   'finished products',
#   'brown bread',
#   'tropical fruit',
#   'bottled beer',
#   'bottled water'],
#  ['hard cheese', 'onions'],
#  ['shopping bags', 'soda'],
#  ['whole milk',
#   'sausage',
#   'frozen vegetables',
#   'oil',
#   'frozen fish',
#   'baking powder',
#   'frozen vegetables'],
#  ['long life bakery product'],
#  ['specialty cheese'],
#  ['other vegetables', 'pasta', 'meat'],
#  ['butter'],
#  ['bottled beer',
#   'citrus fruit',
#   'sausage',
#   'frozen meals',
#   'other vegetables'],
#  ['domestic eggs', 'shopping bags', 'pasta', 'sugar', 'tropical fruit'],
#  ['cling filmbags', 'soda'],
#  ['uhtmilk'],
#  ['rollsbuns', 'shopping bags', 'candy', 'bottled water', 'salty snack'],
#  ['white bread', 'coffee'],
#  ['soft cheese', 'onions'],
#  ['condensed milk', 'shopping bags', 'dessert'],
#  ['processed cheese', 'shopping bags', 'canned fruit', 'soda', 'soda'],
#  ['other vegetables'],
#  ['yogurt'],
#  ['berries', 'tropical fruit'],
#  ['uhtmilk'],
#  ['other vegetables'],
#  ['margarine', 'margarine', 'chicken'],
#  ['skin care',
#   'packaged fruitvegetables',
#   'tropical fruit',
#   'citrus fruit',
#   'root vegetables'],
#  ['curd'],
#  ['whole milk'],
#  ['coffee', 'citrus fruit'],
#  ['frozen meals', 'bottled beer'],
#  ['dessert', 'canned beer', 'fruitvegetable juice'],
#  ['grapes', 'other vegetables'],
#  ['dishes', 'pot plants', 'whole milk', 'soda', 'pork'],
#  ['pastry', 'chicken'],
#  ['pastry'],
#  ['sausage', 'baking powder', 'processed cheese'],
#  ['napkins', 'ham'],
#  ['specialty chocolate'],
#  ['tea'],
#  ['berries'],
#  ['other vegetables'],
#  ['sausage', 'coffee'],
#  ['herbs', 'uhtmilk', 'butter'],
#  ['frozen dessert', 'cream cheese '],
#  ['rollsbuns'],
#  ['yogurt', 'coffee'],
#  ['whippedsour cream', 'fruitvegetable juice'],
#  ['shopping bags', 'berries', 'fruitvegetable juice', 'whole milk'],
#  ['hamburger meat', 'coffee'],
#  ['ice cream'],
#  ['grapes', 'sausage', 'sliced cheese', 'root vegetables'],
#  ['shopping bags', 'pip fruit'],
#  ['curd', 'sausage'],
#  ['canned vegetables', 'whole milk', 'flower seeds'],
#  ['flour', 'hard cheese', 'rollsbuns', 'rollsbuns'],
#  ['whole milk'],
#  ['frozen meals', 'organic sausage'],
#  ['frozen meals', 'bottled beer', 'citrus fruit', 'other vegetables'],
#  ['butter', 'white bread'],
#  ['yogurt',
#   'tropical fruit',
#   'mayonnaise',
#   'tropical fruit',
#   'sausage',
#   'soda'],
#  ['bottled water', 'sugar', 'tropical fruit', 'curd', 'specialty bar'],
#  ['whole milk', 'other vegetables', 'soda'],
#  ['waffles'],
#  ['brown bread', 'hamburger meat'],
#  ['yogurt', 'pork'],
#  ['chicken',
#   'specialty chocolate',
#   'cream cheese ',
#   'tropical fruit',
#   'pip fruit',
#   'shopping bags',
#   'curd',
#   'other vegetables',
#   'citrus fruit',
#   'redblush wine'],
#  ['other vegetables'],
#  ['whole milk', 'butter'],
#  ['brown bread', 'margarine'],
#  ['misc beverages', 'whole milk'],
#  ['canned fish', 'oil'],
#  ['tropical fruit', 'seasonal products', 'root vegetables'],
#  ['canned fruit'],
#  ['softener', 'whole milk'],
#  ['liquor', 'other vegetables'],
#  ['flower soilfertilizer'],
#  ['cereals'],
#  ['napkins', 'pork'],
#  ['specialty bar', 'cleaner'],
#  ['pastry', 'pork'],
#  ['artif sweetener', 'whole milk'],
#  ['rollsbuns', 'tidbits', 'dessert'],
#  ['specialty cheese', 'coffee'],
#  ['domestic eggs', 'shopping bags', 'frozen potato products'],
#  ['dental care', 'ice cream'],
#  ['pastry'],
#  ['onions', 'mustard'],
#  ['hygiene articles', 'curd'],
#  ['root vegetables', 'whole milk', 'other vegetables', 'butter'],
#  ['specialty chocolate', 'citrus fruit', 'white bread', 'salt'],
#  ['dessert', 'house keeping products'],
#  ['yogurt'],
#  ['bottled beer', 'sausage'],
#  ['whole milk', 'cream cheese '],
#  ['condensed milk', 'hard cheese'],
#  ['brown bread', 'butter'],
#  ['shopping bags', 'rollsbuns'],
#  ['photofilm',
#   'white bread',
#   'whole milk',
#   'whole milk',
#   'pot plants',
#   'yogurt'],
#  ['other vegetables'],
#  ['root vegetables', 'newspapers'],
#  ['citrus fruit', 'photofilm'],
#  ['canned beer',
#   'cookware',
#   'bottled water',
#   'butter',
#   'meat',
#   'canned beer',
#   'root vegetables',
#   'ice cream',
#   'frozen vegetables'],
#  ['oil'],
#  ['soda'],
#  ['yogurt', 'rollsbuns', 'tropical fruit'],
#  ['root vegetables', 'ham'],
#  ['whole milk', 'whole milk', 'sausage', 'beverages'],
#  ['finished products', 'rollsbuns'],
#  ['spices', 'ice cream', 'spices'],
#  ['uhtmilk'],
#  ['hamburger meat'],
#  ['finished products'],
#  ['shopping bags', 'other vegetables', 'shopping bags'],
#  ['yogurt'],
#  ['bottled water', 'pork'],
#  ['butter', 'bottled water'],
#  ['cream cheese ', 'onions', 'whole milk'],
#  ['bottled water',
#   'bottled water',
#   'specialty bar',
#   'whippedsour cream',
#   'newspapers'],
#  ['chicken'],
#  ['uhtmilk', 'frozen vegetables'],
#  ['soups', 'salty snack'],
#  ['margarine'],
#  ['ice cream', 'napkins', 'bottled water', 'shopping bags', 'tropical fruit'],
#  ['rollsbuns', 'butter'],
#  ['pastry'],
#  ['hygiene articles', 'yogurt'],
#  ['long life bakery product'],
#  ['pickled vegetables', 'domestic eggs', 'pork'],
#  ['hygiene articles'],
#  ['chewing gum', 'root vegetables'],
#  ['yogurt', 'dessert', 'herbs'],
#  ['soda'],
#  ['flower seeds', 'whippedsour cream', 'canned fruit', 'soft cheese'],
#  ['pip fruit', 'margarine', 'whole milk', 'butter'],
#  ['abrasive cleaner', 'napkins', 'rollsbuns', 'whole milk', 'whole milk'],
#  ['rollsbuns', 'napkins'],
#  ['herbs', 'prosecco', 'yogurt'],
#  ['brown bread', 'other vegetables', 'canned beer'],
#  ['margarine', 'rice'],
#  ['other vegetables', 'yogurt', 'margarine'],
#  ['sugar', 'rollsbuns'],
#  ['tropical fruit',
#   'domestic eggs',
#   'rollsbuns',
#   'citrus fruit',
#   'domestic eggs'],
#  ['rollsbuns', 'whole milk'],
#  ['whole milk', 'oil'],
#  ['pork', 'beverages'],
#  ['canned beer'],
#  ['whole milk', 'light bulbs'],
#  ['specialty fat', 'tropical fruit', 'dessert', 'pip fruit'],
#  ['whole milk'],
#  ['dishes', 'hygiene articles'],
#  ['root vegetables', 'soda', 'waffles', 'domestic eggs', 'other vegetables'],
#  ['whippedsour cream', 'soft cheese'],
#  ['other vegetables'],
#  ['bottled water', 'sausage'],
#  ['chicken', 'dessert', 'frankfurter'],
#  ['pickled vegetables', 'long life bakery product'],
#  ['flower seeds', 'soft cheese'],
#  ['rice', 'bottled beer'],
#  ['root vegetables', 'pip fruit', 'beverages'],
#  ['meat', 'hard cheese', 'jam', 'tropical fruit'],
#  ['other vegetables', 'yogurt'],
#  ['yogurt', 'redblush wine'],
#  ['domestic eggs', 'sausage', 'herbs'],
#  ['chicken', 'napkins'],
#  ['rollsbuns', 'pastry'],
#  ['chicken', 'soda'],
#  ['instant food products', 'bottled beer'],
#  ['yogurt', 'rollsbuns'],
#  ['white bread', 'canned beer'],
#  ['other vegetables', 'whole milk', 'bottled beer'],
#  ['chicken', 'yogurt'],
#  ['roll products ', 'whippedsour cream'],
#  ['pot plants', 'pip fruit'],
#  ['soda', 'frozen vegetables', 'sausage'],
#  ['hard cheese', 'shopping bags'],
#  ['root vegetables'],
#  ['butter'],
#  ['detergent'],
#  ['tropical fruit', 'pastry'],
#  ['canned beer', 'whole milk', 'bottled beer'],
#  ['whole milk', 'pastry'],
#  ['canned fish', 'pasta', 'margarine'],
#  ['hamburger meat'],
#  ['dishes', 'whippedsour cream', 'rollsbuns'],
#  ['frankfurter'],
#  ['spread cheese', 'root vegetables'],
#  ['sausage', 'citrus fruit', 'flower seeds', 'yogurt', 'pork', 'white wine'],
#  ['pork', 'whole milk', 'yogurt'],
#  ['yogurt'],
#  ['rollsbuns', 'whole milk'],
#  ['pastry', 'canned beer'],
#  ['sugar'],
#  ['hamburger meat'],
#  ['pastry', 'baking powder', 'sausage', 'meat'],
#  ['waffles'],
#  ['whole milk', 'pastry', 'napkins'],
#  ['root vegetables'],
#  ['pickled vegetables', 'sausage', 'margarine', 'pastry', 'whippedsour cream'],
#  ['curd', 'whippedsour cream'],
#  ['tropical fruit', 'cocoa drinks'],
#  ['newspapers'],
#  ['other vegetables'],
#  ['redblush wine', 'canned beer', 'rollsbuns'],
#  ['mustard', 'berries'],
#  ['skin care', 'pip fruit'],
#  ['tropical fruit'],
#  ['butter',
#   'long life bakery product',
#   'waffles',
#   'soft cheese',
#   'canned vegetables',
#   'hamburger meat'],
#  ['frankfurter'],
#  ['other vegetables'],
#  ['ice cream', 'canned beer'],
#  ['hygiene articles'],
#  ['rollsbuns', 'packaged fruitvegetables', 'chocolate'],
#  ['whippedsour cream'],
#  ['curd', 'bottled beer'],
#  ['frozen vegetables', 'curd'],
#  ['specialty cheese', 'onions'],
#  ['sausage', 'rollsbuns'],
#  ['other vegetables', 'citrus fruit'],
#  ['mustard', 'yogurt'],
#  ['flour', 'pastry', 'specialty bar'],
#  ['pork', 'frozen meals'],
#  ['pip fruit'],
#  ['misc beverages', 'soda', 'rice'],
#  ['processed cheese',
#   'coffee',
#   'mayonnaise',
#   'root vegetables',
#   'bottled beer'],
#  ['finished products'],
#  ['soda'],
#  ['soda', 'bottled beer'],
#  ['bottled beer', 'waffles', 'chewing gum', 'chicken', 'meat'],
#  ['hygiene articles', 'rollsbuns'],
#  ['whole milk'],
#  ['syrup', 'whole milk'],
#  ['soups', 'beef'],
#  ['processed cheese', 'specialty bar', 'yogurt'],
#  ['white wine',
#   'bottled water',
#   'whole milk',
#   'specialty chocolate',
#   'rollsbuns',
#   'misc beverages',
#   'curd'],
#  ['chocolate', 'soda'],
#  ['napkins', 'soda'],
#  ['packaged fruitvegetables'],
#  ['ice cream', 'frozen vegetables', 'cereals', 'yogurt'],
#  ['sugar'],
#  ['other vegetables',
#   'pastry',
#   'roll products ',
#   'canned vegetables',
#   'shopping bags'],
#  ['bottled beer', 'sausage', 'chicken'],
#  ['bottled beer', 'curd', 'rollsbuns'],
#  ['other vegetables', 'bottled beer'],
#  ['cream cheese ', 'pastry'],
#  ['butter', 'sausage', 'whole milk', 'shopping bags'],
#  ['misc beverages', 'domestic eggs', 'whippedsour cream'],
#  ['sausage', 'dishes', 'frozen vegetables', 'sausage'],
#  ['hamburger meat'],
#  ['curd', 'whole milk'],
#  ['soda', 'soda'],
#  ['berries', 'soda'],
#  ['newspapers', 'processed cheese'],
#  ['fruitvegetable juice', 'tropical fruit'],
#  ['sausage', 'whippedsour cream', 'misc beverages'],
#  ['domestic eggs'],
#  ['root vegetables', 'other vegetables'],
#  ['other vegetables', 'condensed milk'],
#  ['root vegetables', 'hard cheese'],
#  ['root vegetables',
#   'rollsbuns',
#   'bottled water',
#   'citrus fruit',
#   'instant food products',
#   'mayonnaise',
#   'processed cheese',
#   'canned fish'],
#  ['pastry'],
#  ['curd', 'butter'],
#  ['bottled water'],
#  ['other vegetables', 'citrus fruit'],
#  ['chocolate', 'frozen vegetables', 'canned beer'],
#  ['butter', 'bottled beer', 'onions'],
#  ['oil', 'dishes', 'domestic eggs', 'waffles'],
#  ['frankfurter'],
#  ['waffles', 'onions'],
#  ['grapes', 'yogurt', 'whippedsour cream'],
#  ['domestic eggs', 'napkins', 'rollsbuns'],
#  ['citrus fruit', 'frozen meals'],
#  ['pet care', 'coffee', 'flour', 'napkins'],
#  ['napkins', 'cling filmbags'],
#  ['bottled water'],
#  ['meat', 'curd'],
#  ['uhtmilk', 'canned beer', 'whole milk'],
#  ['margarine'],
#  ['vinegar', 'grapes'],
#  ['tropical fruit', 'other vegetables', 'sausage'],
#  ['whole milk', 'whole milk', 'bottled water', 'frozen vegetables'],
#  ['whole milk'],
#  ['flour', 'mustard'],
#  ['citrus fruit',
#   'rollsbuns',
#   'root vegetables',
#   'whole milk',
#   'pastry',
#   'whole milk'],
#  ['whippedsour cream', 'brown bread'],
#  ['chocolate', 'yogurt', 'honey'],
#  ['root vegetables', 'bottled beer', 'pastry', 'bottled water'],
#  ['other vegetables'],
#  ['frankfurter', 'berries'],
#  ['bottled water', 'rollsbuns'],
#  ['dessert'],
#  ['rice', 'frozen vegetables', 'tropical fruit'],
#  ['shopping bags', 'other vegetables'],
#  ['specialty chocolate', 'other vegetables'],
#  ['syrup', 'sliced cheese', 'soda'],
#  ['rollsbuns', 'soda', 'shopping bags'],
#  ['citrus fruit', 'whole milk'],
#  ['grapes', 'frankfurter', 'napkins', 'soda', 'salt'],
#  ['white wine'],
#  ['tropical fruit', 'other vegetables'],
#  ['pip fruit', 'domestic eggs'],
#  ['semifinished bread'],
#  ['beef'],
#  ['beef', 'ketchup', 'pastry', 'whole milk', 'rollsbuns'],
#  ['chocolate', 'bottled beer'],
#  ['soda', 'beef'],
#  ['cat food', 'curd'],
#  ['domestic eggs'],
#  ['frankfurter', 'butter', 'hard cheese'],
#  ['bottled water', 'herbs', 'whole milk', 'whole milk'],
#  ['coffee', 'detergent'],
#  ['meat', 'other vegetables'],
#  ['bottled water', 'tropical fruit'],
#  ['other vegetables'],
#  ['baking powder', 'cooking chocolate', 'rollsbuns'],
#  ['tropical fruit', 'rollsbuns', 'specialty bar', 'newspapers', 'meat'],
#  ['pork', 'beef', 'salty snack', 'bottled water', 'beef'],
#  ['redblush wine', 'cream cheese '],
#  ['bottled beer', 'hard cheese'],
#  ['domestic eggs', 'soda'],
#  ['frozen vegetables'],
#  ['pastry', 'bottled beer', 'canned beer'],
#  ['ice cream', 'soda'],
#  ['rollsbuns',
#   'soda',
#   'sugar',
#   'yogurt',
#   'pastry',
#   'tropical fruit',
#   'yogurt',
#   'bottled water'],
#  ['processed cheese', 'frankfurter'],
#  ['cat food', 'butter milk', 'napkins', 'shopping bags'],
#  ['berries'],
#  ['semifinished bread'],
#  ['hard cheese'],
#  ['canned beer'],
#  ['brown bread', 'ham'],
#  ['soda', 'brown bread'],
#  ['instant food products'],
#  ['whippedsour cream',
#   'yogurt',
#   'whippedsour cream',
#   'vinegar',
#   'chocolate',
#   'whole milk',
#   'whole milk'],
#  ['tropical fruit', 'frozen fish', 'soda'],
#  ['ketchup'],
#  ['processed cheese', 'curd'],
#  ['white bread', 'grapes'],
#  ['pastry', 'ham', 'soda', 'pork', 'citrus fruit', 'tropical fruit'],
#  ['salty snack', 'rollsbuns'],
#  ['rollsbuns', 'whole milk', 'hard cheese', 'soda'],
#  ['liquor', 'other vegetables'],
#  ['mustard', 'rollsbuns'],
#  ['salt', 'sausage'],
#  ['mustard', 'tropical fruit'],
#  ['bottled water', 'whole milk'],
#  ['bottled beer'],
#  ['whole milk', 'dish cleaner', 'whole milk'],
#  ...]

# %% [markdown]
# ### 3. Prepare data

# %%
# transaction encoder initialisation
encoder = TransactionEncoder()
encoder
# Out:
# TransactionEncoder()

# %%
# convert to a format for frequent itemset mining
encoded_array = encoder.fit_transform(transactions)
encoded_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
# create dataframe
df = pd.DataFrame(encoded_array, columns=encoder.columns_)
df
# Out:
#        abrasive cleaner  artif sweetener  baby cosmetics   bags  \
# 0                 False            False           False  False
# 1                 False            False           False  False
# 2                 False            False           False  False
# 3                 False            False           False  False
# 4                 False            False           False  False
# ...                 ...              ...             ...    ...
# 11307             False            False           False  False
# 11308             False            False           False  False
# 11309             False            False           False  False
# 11310             False            False           False  False
# 11311             False            False           False  False
#
#        baking powder  bathroom cleaner   beef  berries  beverages  \
# 0              False             False  False    False      False
# 1              False             False  False    False      False
# 2              False             False  False    False      False
# 3              False             False  False    False      False
# 4              False             False  False    False      False
# ...              ...               ...    ...      ...        ...
# 11307          False             False  False    False      False
# 11308          False             False  False    False      False
# 11309          False             False  False    False      False
# 11310          False             False  False    False      False
# 11311          False             False  False    False      False
#
#        bottled beer  ...  uhtmilk  vinegar  waffles  whippedsour cream  \
# 0             False  ...    False    False    False              False
# 1             False  ...    False    False    False              False
# 2             False  ...    False    False    False              False
# 3             False  ...    False    False    False              False
# 4             False  ...    False    False    False              False
# ...             ...  ...      ...      ...      ...                ...
# 11307         False  ...    False    False    False              False
# 11308         False  ...    False    False    False              False
# 11309         False  ...    False    False    False              False
# 11310         False  ...    False    False    False              False
# 11311         False  ...    False    False    False              False
#
#        whisky  white bread  white wine  whole milk  yogurt  zwieback
# 0       False        False       False       False   False     False
# 1       False        False       False       False    True     False
# 2       False        False       False       False   False     False
# 3       False        False       False       False   False     False
# 4       False        False       False       False   False     False
# ...       ...          ...         ...         ...     ...       ...
# 11307   False        False       False       False   False     False
# 11308   False        False       False       False   False     False
# 11309   False        False       False       False   False     False
# 11310   False        False       False       False   False     False
# 11311   False        False       False       False   False     False
#
# [11312 rows x 167 columns]

# %% [markdown]
# ### 4. Apply FP-Growth algorithm to train data

# %% [markdown]
# The system requires scaling up to 1 million customer transactions. The Frequent Patterns (FP) Growth algorithm is recommended because many grocery transactions likely follow the same path, allowing for high data compaction. Thus, the FP-Growth algorithm is more efficient, providing the same results as the Apriori algorithm with improved performance. [2]
#
# The recommended parameter values are as follows: [5]
#
# * For 1,000,000 transactions, set the minimum support to 0.001. This considers only the itemsets that occur at least 1,000 times in total transactions.
#
# * For handling 1,000 frequent itemsets, set the minimum confidence to 0.1. This considers the rules where the items appear together with the given itemsets more than 10% of the time.
#
# * Consider only the association rules that increase the likelihood of purchasing items together - a lift value greater than 1 is recommended to help store managers increase sales.

# %%
# create frequent itemsets
frequent_itemsets = fpgrowth(df, min_support=0.001, use_colnames=True) # 
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)

print("Frequent itemsets:\n", frequent_itemsets)
# Out:
# Frequent itemsets:
#        support                        itemsets
# 7    0.141089                    (whole milk)
# 29   0.111386              (other vegetables)
# 8    0.100690                     (rollsbuns)
# 3    0.089905                          (soda)
# 1    0.078324                        (yogurt)
# ..        ...                             ...
# 378  0.001061     (chocolate, tropical fruit)
# 123  0.001061                   (ready soups)
# 406  0.001061      (domestic eggs, margarine)
# 667  0.001061           (salty snack, yogurt)
# 728  0.001061  (whole milk, liquor appetizer)
#
# [729 rows x 2 columns]

# %%
# generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
rules = rules[rules['lift'] > 1]

if not rules.empty:
    print("Association rules:\n", rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
else:
    print("No rules generated.")
# Out:
# Association rules:
#                     antecedents   consequents   support  confidence      lift
# 0                 (whole milk)   (rollsbuns)  0.014940    0.105890  1.051646
# 1                  (rollsbuns)  (whole milk)  0.014940    0.148376  1.051646
# 4                     (yogurt)  (whole milk)  0.011227    0.143341  1.015960
# 6                    (sausage)  (whole milk)  0.009017    0.165584  1.173616
# 7              (bottled water)  (whole milk)  0.008310    0.144838  1.026573
# ..                         ...           ...       ...         ...       ...
# 182       (pickled vegetables)   (rollsbuns)  0.001061    0.127660  1.267853
# 183         (processed cheese)      (yogurt)  0.001061    0.105263  1.343947
# 184        (soda, canned beer)  (whole milk)  0.001061    0.307692  2.180837
# 185  (canned beer, whole milk)        (soda)  0.001061    0.166667  1.853818
# 186         (liquor appetizer)  (whole milk)  0.001061    0.266667  1.890058
#
# [122 rows x 5 columns]

# %% [markdown]
# ### 5. Apply association rules to test data

# %%
# load test data
test_data = pd.read_csv('Groceries data test.csv', header=0)

# %%
# check item & preprocess item

# to lower string
test_data["itemDescription"] = test_data["itemDescription"].str.lower()

# remove special characters/punctuation
test_data["itemDescription"] = test_data["itemDescription"].str.replace(r'[^\w\s]+', '', regex=True)

# %%
# group data
test_data['Date'] = pd.to_datetime(test_data['Date'], format="%d/%m/%Y")
test_data['Year'] = test_data['Date'].dt.year
test_data['Quarter'] = test_data['Date'].dt.to_period('Q')
test_grouped = test_data.groupby(['Member_number', 'Year', 'Quarter'])['itemDescription'].apply(list).reset_index()
test_grouped
# Out:
#       Member_number  Year Quarter                        itemDescription
# 0              1000  2014  2014Q2              [whole milk, salty snack]
# 1              1000  2015  2015Q1       [semifinished bread, whole milk]
# 2              1000  2015  2015Q4                     [hygiene articles]
# 3              1001  2015  2015Q1                          [frankfurter]
# 4              1002  2014  2014Q3                     [other vegetables]
# ...             ...   ...     ...                                    ...
# 7683           4999  2014  2014Q2                            [detergent]
# 7684           4999  2015  2015Q1                      [berries, yogurt]
# 7685           4999  2015  2015Q2                    [whippedsour cream]
# 7686           5000  2014  2014Q4                         [bottled beer]
# 7687           5000  2015  2015Q4  [semifinished bread, root vegetables]
#
# [7688 rows x 4 columns]

# %%
# convert to transaction data
test_transactions = test_grouped['itemDescription'].tolist()
test_transactions
# Out:
# [['whole milk', 'salty snack'],
#  ['semifinished bread', 'whole milk'],
#  ['hygiene articles'],
#  ['frankfurter'],
#  ['other vegetables'],
#  ['specialty chocolate'],
#  ['frozen meals', 'rollsbuns'],
#  ['rollsbuns'],
#  ['tropical fruit'],
#  ['root vegetables'],
#  ['rollsbuns', 'other vegetables', 'chocolate', 'packaged fruitvegetables'],
#  ['bottled water', 'rollsbuns'],
#  ['whole milk'],
#  ['skin care'],
#  ['whole milk'],
#  ['liquor appetizer'],
#  ['soda', 'yogurt', 'root vegetables'],
#  ['newspapers', 'yogurt'],
#  ['ketchup'],
#  ['frankfurter'],
#  ['rollsbuns', 'candles'],
#  ['yogurt'],
#  ['root vegetables'],
#  ['mustard', 'hard cheese', 'whippedsour cream', 'napkins', 'tropical fruit'],
#  ['white bread', 'roll products ', 'whole milk'],
#  ['whole milk', 'rollsbuns', 'hamburger meat'],
#  ['canned beer'],
#  ['rollsbuns'],
#  ['salty snack'],
#  ['citrus fruit'],
#  ['uhtmilk'],
#  ['oil', 'chicken'],
#  ['yogurt'],
#  ['soda', 'shopping bags'],
#  ['berries'],
#  ['butter milk'],
#  ['redblush wine'],
#  ['whole milk'],
#  ['soda', 'curd', 'frozen meals'],
#  ['whippedsour cream'],
#  ['berries'],
#  ['yogurt', 'rollsbuns'],
#  ['canned beer', 'whippedsour cream'],
#  ['softener'],
#  ['rollsbuns'],
#  ['onions'],
#  ['other vegetables', 'berries'],
#  ['whole milk'],
#  ['cream cheese '],
#  ['whippedsour cream', 'ice cream'],
#  ['fruitvegetable juice', 'rollsbuns'],
#  ['tropical fruit'],
#  ['cat food', 'pip fruit', 'yogurt', 'cling filmbags'],
#  ['newspapers', 'frozen meals'],
#  ['frozen vegetables'],
#  ['white bread', 'white wine'],
#  ['frozen vegetables', 'sausage'],
#  ['fruitvegetable juice'],
#  ['chewing gum'],
#  ['frankfurter', 'yogurt'],
#  ['cake bar'],
#  ['pasta'],
#  ['rollsbuns'],
#  ['root vegetables', 'white bread'],
#  ['tropical fruit'],
#  ['chicken', 'whole milk', 'tropical fruit', 'candy'],
#  ['dessert', 'other vegetables', 'whole milk'],
#  ['whole milk'],
#  ['whole milk'],
#  ['tropical fruit'],
#  ['yogurt', 'instant food products'],
#  ['onions'],
#  ['whole milk'],
#  ['butter'],
#  ['tropical fruit'],
#  ['specialty bar'],
#  ['whole milk'],
#  ['herbs'],
#  ['beverages', 'waffles'],
#  ['house keeping products'],
#  ['bottled beer'],
#  ['pork'],
#  ['grapes', 'root vegetables'],
#  ['beef'],
#  ['butter'],
#  ['chewing gum', 'bottled water'],
#  ['yogurt'],
#  ['detergent', 'pork', 'shopping bags', 'yogurt'],
#  ['soda'],
#  ['whole milk'],
#  ['hamburger meat'],
#  ['fruitvegetable juice'],
#  ['bottled beer'],
#  ['frankfurter'],
#  ['photofilm', 'other vegetables'],
#  ['white wine'],
#  ['newspapers'],
#  ['whippedsour cream'],
#  ['pickled vegetables', 'soda', 'soda'],
#  ['chicken', 'other vegetables'],
#  ['yogurt'],
#  ['bottled water'],
#  ['root vegetables', 'other vegetables'],
#  ['spread cheese'],
#  ['bottled beer', 'fruitvegetable juice'],
#  ['chocolate'],
#  ['sauces'],
#  ['other vegetables', 'tropical fruit'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['other vegetables'],
#  ['tropical fruit'],
#  ['rollsbuns', 'tropical fruit'],
#  ['redblush wine', 'frozen fish'],
#  ['tropical fruit'],
#  ['shopping bags'],
#  ['whole milk'],
#  ['chocolate', 'pork'],
#  ['yogurt'],
#  ['pork'],
#  ['domestic eggs', 'salt'],
#  ['sliced cheese'],
#  ['citrus fruit'],
#  ['fruitvegetable juice'],
#  ['salt'],
#  ['bottled water'],
#  ['finished products', 'dishes'],
#  ['pip fruit'],
#  ['candy'],
#  ['ketchup', 'semifinished bread'],
#  ['flower seeds'],
#  ['rollsbuns'],
#  ['frankfurter', 'dishes'],
#  ['sausage'],
#  ['bottled water', 'butter'],
#  ['coffee', 'whole milk', 'sausage'],
#  ['pasta', 'other vegetables', 'canned beer'],
#  ['rollsbuns'],
#  ['frankfurter', 'curd'],
#  ['rollsbuns'],
#  ['canned beer'],
#  ['baking powder',
#   'tropical fruit',
#   'whole milk',
#   'specialty bar',
#   'yogurt',
#   'tropical fruit'],
#  ['other vegetables'],
#  ['bottled water'],
#  ['margarine'],
#  ['bathroom cleaner'],
#  ['pork'],
#  ['pip fruit'],
#  ['other vegetables', 'shopping bags'],
#  ['root vegetables'],
#  ['canned beer'],
#  ['curd'],
#  ['beverages', 'sausage'],
#  ['whole milk'],
#  ['whole milk'],
#  ['jam'],
#  ['pip fruit'],
#  ['herbs', 'cake bar'],
#  ['yogurt'],
#  ['tropical fruit', 'other vegetables'],
#  ['sauces'],
#  ['beef'],
#  ['whisky', 'sausage'],
#  ['newspapers'],
#  ['root vegetables', 'other vegetables', 'frozen vegetables'],
#  ['rollsbuns'],
#  ['domestic eggs'],
#  ['other vegetables', 'waffles'],
#  ['detergent', 'flour'],
#  ['tropical fruit'],
#  ['whole milk'],
#  ['yogurt'],
#  ['flour'],
#  ['bottled water', 'packaged fruitvegetables', 'pork'],
#  ['pip fruit', 'fruitvegetable juice'],
#  ['shopping bags', 'root vegetables'],
#  ['whole milk'],
#  ['hard cheese'],
#  ['whole milk', 'tropical fruit', 'curd'],
#  ['frankfurter'],
#  ['tropical fruit', 'whole milk', 'frankfurter'],
#  ['napkins', 'canned beer'],
#  ['grapes'],
#  ['pasta'],
#  ['hygiene articles', 'pudding powder', 'butter milk'],
#  ['whole milk', 'processed cheese'],
#  ['other vegetables'],
#  ['candy'],
#  ['yogurt'],
#  ['ice cream'],
#  ['yogurt'],
#  ['yogurt'],
#  ['yogurt'],
#  ['newspapers', 'specialty fat'],
#  ['rollsbuns', 'semifinished bread', 'pastry'],
#  ['citrus fruit', 'shopping bags'],
#  ['citrus fruit'],
#  ['specialty cheese', 'canned beer'],
#  ['pastry', 'oil'],
#  ['whole milk'],
#  ['curd'],
#  ['frozen vegetables'],
#  ['liquor'],
#  ['chocolate', 'salty snack', 'bottled water'],
#  ['baking powder', 'margarine', 'pastry'],
#  ['uhtmilk'],
#  ['whippedsour cream', 'other vegetables'],
#  ['newspapers', 'jam'],
#  ['curd'],
#  ['whole milk'],
#  ['domestic eggs'],
#  ['root vegetables', 'salty snack'],
#  ['root vegetables', 'citrus fruit'],
#  ['dessert', 'misc beverages', 'white bread'],
#  ['butter'],
#  ['whippedsour cream'],
#  ['other vegetables'],
#  ['soda', 'brown bread'],
#  ['cream cheese ', 'liquor', 'other vegetables'],
#  ['chicken', 'white bread', 'bottled water'],
#  ['whippedsour cream', 'whole milk'],
#  ['berries', 'condensed milk'],
#  ['whole milk'],
#  ['soda', 'newspapers'],
#  ['citrus fruit', 'chocolate marshmallow'],
#  ['other vegetables'],
#  ['chicken', 'dishes'],
#  ['root vegetables'],
#  ['frozen vegetables'],
#  ['canned vegetables'],
#  ['margarine'],
#  ['sausage'],
#  ['rollsbuns'],
#  ['napkins', 'whole milk', 'newspapers', 'long life bakery product'],
#  ['frankfurter', 'shopping bags'],
#  ['pastry'],
#  ['frozen vegetables'],
#  ['frankfurter'],
#  ['tea', 'specialty chocolate', 'brown bread', 'shopping bags'],
#  ['margarine'],
#  ['softener'],
#  ['cream cheese '],
#  ['root vegetables'],
#  ['semifinished bread'],
#  ['soda'],
#  ['yogurt'],
#  ['sausage', 'whole milk'],
#  ['newspapers'],
#  ['other vegetables'],
#  ['other vegetables', 'whole milk'],
#  ['instant coffee', 'fruitvegetable juice'],
#  ['butter milk', 'other vegetables'],
#  ['tropical fruit', 'tropical fruit'],
#  ['other vegetables'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['tropical fruit', 'canned beer'],
#  ['tropical fruit', 'misc beverages'],
#  ['cling filmbags'],
#  ['soda'],
#  ['tropical fruit', 'rollsbuns'],
#  ['berries'],
#  ['soups'],
#  ['chicken', 'brown bread'],
#  ['soda'],
#  ['soda'],
#  ['coffee'],
#  ['soda', 'domestic eggs', 'meat'],
#  ['white bread'],
#  ['soda', 'bottled beer'],
#  ['tropical fruit'],
#  ['other vegetables', 'pip fruit'],
#  ['whole milk'],
#  ['detergent'],
#  ['root vegetables', 'soda', 'other vegetables', 'long life bakery product'],
#  ['yogurt'],
#  ['dog food', 'baking powder'],
#  ['pork'],
#  ['chicken', 'soda'],
#  ['long life bakery product'],
#  ['berries'],
#  ['canned beer'],
#  ['berries', 'pastry'],
#  ['curd cheese', 'soda'],
#  ['rollsbuns', 'whole milk'],
#  ['pork'],
#  ['tropical fruit', 'rollsbuns'],
#  ['cake bar'],
#  ['whole milk'],
#  ['ice cream', 'butter'],
#  ['whole milk'],
#  ['soft cheese'],
#  ['rollsbuns'],
#  ['sausage'],
#  ['house keeping products', 'whole milk', 'frankfurter', 'brandy'],
#  ['napkins', 'whole milk'],
#  ['bottled water', 'whole milk'],
#  ['citrus fruit'],
#  ['citrus fruit', 'soda'],
#  ['butter'],
#  ['domestic eggs', 'beef'],
#  ['pip fruit'],
#  ['bottled beer'],
#  ['whole milk'],
#  ['white bread', 'yogurt', 'fruitvegetable juice'],
#  ['coffee'],
#  ['salty snack', 'redblush wine'],
#  ['canned beer', 'citrus fruit'],
#  ['white bread', 'frozen vegetables'],
#  ['sausage'],
#  ['whole milk', 'bottled water', 'newspapers'],
#  ['other vegetables', 'whole milk'],
#  ['whole milk', 'beef', 'house keeping products'],
#  ['herbs', 'long life bakery product'],
#  ['uhtmilk'],
#  ['other vegetables', 'waffles', 'soda', 'detergent', 'rollsbuns'],
#  ['whippedsour cream', 'liquor', 'newspapers'],
#  ['chocolate'],
#  ['whippedsour cream', 'pip fruit'],
#  ['sparkling wine', 'whole milk'],
#  ['citrus fruit'],
#  ['turkey'],
#  ['onions'],
#  ['newspapers'],
#  ['citrus fruit'],
#  ['cling filmbags'],
#  ['pip fruit'],
#  ['soft cheese', 'rollsbuns'],
#  ['hamburger meat'],
#  ['pasta', 'oil'],
#  ['berries', 'bottled water'],
#  ['citrus fruit'],
#  ['whole milk'],
#  ['tropical fruit', 'other vegetables'],
#  ['curd cheese', 'frozen potato products'],
#  ['whole milk'],
#  ['pastry'],
#  ['dessert'],
#  ['shopping bags'],
#  ['coffee'],
#  ['pork'],
#  ['chocolate'],
#  ['chicken'],
#  ['whole milk', 'bottled beer'],
#  ['mayonnaise'],
#  ['butter'],
#  ['rollsbuns'],
#  ['whole milk', 'soft cheese', 'hamburger meat', 'butter milk'],
#  ['butter', 'brown bread', 'pastry'],
#  ['butter', 'bottled beer'],
#  ['beef', 'whole milk'],
#  ['whole milk'],
#  ['specialty bar'],
#  ['white bread'],
#  ['detergent', 'soda'],
#  ['whole milk'],
#  ['citrus fruit', 'soda'],
#  ['other vegetables'],
#  ['soda'],
#  ['dessert'],
#  ['soda', 'hamburger meat'],
#  ['whippedsour cream'],
#  ['waffles'],
#  ['seasonal products'],
#  ['bottled water', 'honey'],
#  ['soda'],
#  ['domestic eggs'],
#  ['candy'],
#  ['waffles', 'pip fruit'],
#  ['beef'],
#  ['chocolate'],
#  ['yogurt'],
#  ['misc beverages', 'yogurt', 'sliced cheese', 'citrus fruit'],
#  ['specialty chocolate'],
#  ['canned vegetables', 'white bread', 'popcorn', 'whole milk', 'flour'],
#  ['candy', 'dessert'],
#  ['coffee', 'candles'],
#  ['roll products '],
#  ['rollsbuns'],
#  ['waffles', 'pastry', 'root vegetables', 'soda'],
#  ['chicken', 'bottled beer'],
#  ['curd', 'white bread'],
#  ['tropical fruit', 'candles'],
#  ['whole milk', 'rollsbuns', 'pastry'],
#  ['whole milk', 'frankfurter'],
#  ['soft cheese'],
#  ['pork', 'beef'],
#  ['rollsbuns', 'frozen meals'],
#  ['sausage'],
#  ['ham'],
#  ['long life bakery product'],
#  ['whole milk', 'finished products', 'domestic eggs'],
#  ['butter', 'frankfurter', 'yogurt'],
#  ['tropical fruit'],
#  ['cat food'],
#  ['chicken', 'newspapers'],
#  ['fruitvegetable juice', 'citrus fruit'],
#  ['syrup'],
#  ['grapes'],
#  ['semifinished bread'],
#  ['canned beer', 'brown bread'],
#  ['soda', 'tropical fruit'],
#  ['grapes'],
#  ['pastry'],
#  ['pork'],
#  ['butter', 'yogurt', 'sausage', 'other vegetables'],
#  ['meat', 'tropical fruit'],
#  ['instant coffee'],
#  ['canned beer'],
#  ['pastry', 'rollsbuns', 'dental care', 'onions'],
#  ['ice cream'],
#  ['rum'],
#  ['uhtmilk'],
#  ['butter milk'],
#  ['photofilm'],
#  ['soda'],
#  ['whippedsour cream'],
#  ['photofilm'],
#  ['ham', 'whippedsour cream'],
#  ['canned beer'],
#  ['whole milk', 'other vegetables'],
#  ['margarine', 'yogurt'],
#  ['ice cream'],
#  ['whippedsour cream', 'photofilm'],
#  ['root vegetables', 'flour'],
#  ['canned beer'],
#  ['rollsbuns', 'bottled beer'],
#  ['curd', 'rollsbuns', 'other vegetables'],
#  ['whippedsour cream'],
#  ['whole milk', 'butter milk'],
#  ['margarine', 'root vegetables'],
#  ['shopping bags', 'coffee'],
#  ['curd', 'pastry'],
#  ['root vegetables'],
#  ['canned beer', 'other vegetables', 'other vegetables', 'dog food'],
#  ['sausage', 'sausage'],
#  ['butter milk'],
#  ['sugar'],
#  ['white bread'],
#  ['condensed milk', 'sausage'],
#  ['other vegetables', 'rollsbuns'],
#  ['oil', 'margarine'],
#  ['pasta', 'specialty chocolate', 'soda'],
#  ['whole milk'],
#  ['chocolate'],
#  ['dog food', 'sausage', 'bottled water'],
#  ['beverages', 'beverages'],
#  ['soft cheese'],
#  ['soda'],
#  ['rollsbuns'],
#  ['turkey', 'soda', 'shopping bags'],
#  ['tropical fruit', 'grapes', 'rollsbuns'],
#  ['whippedsour cream', 'yogurt', 'canned beer'],
#  ['other vegetables'],
#  ['frozen vegetables'],
#  ['candy', 'butter'],
#  ['butter'],
#  ['pip fruit', 'dessert', 'frozen vegetables'],
#  ['beef'],
#  ['frankfurter'],
#  ['soda'],
#  ['chewing gum', 'other vegetables'],
#  ['turkey'],
#  ['liqueur'],
#  ['specialty cheese'],
#  ['white wine', 'specialty bar'],
#  ['redblush wine', 'soda'],
#  ['coffee'],
#  ['domestic eggs'],
#  ['sugar'],
#  ['oil'],
#  ['yogurt'],
#  ['rollsbuns', 'frozen vegetables'],
#  ['whole milk'],
#  ['pork', 'napkins'],
#  ['domestic eggs'],
#  ['pickled vegetables', 'onions'],
#  ['sugar'],
#  ['tropical fruit'],
#  ['semifinished bread', 'other vegetables'],
#  ['pastry'],
#  ['root vegetables', 'canned fish', 'uhtmilk'],
#  ['pork', 'other vegetables', 'domestic eggs'],
#  ['pastry'],
#  ['sliced cheese'],
#  ['other vegetables'],
#  ['white wine', 'sauces'],
#  ['rollsbuns'],
#  ['redblush wine', 'frozen meals'],
#  ['other vegetables'],
#  ['whole milk', 'butter milk'],
#  ['cake bar'],
#  ['citrus fruit'],
#  ['cream cheese '],
#  ['other vegetables'],
#  ['butter milk'],
#  ['rollsbuns', 'butter'],
#  ['citrus fruit'],
#  ['sausage'],
#  ['dessert'],
#  ['hard cheese'],
#  ['whole milk', 'rollsbuns'],
#  ['semifinished bread'],
#  ['frankfurter', 'sausage'],
#  ['dessert'],
#  ['whippedsour cream'],
#  ['hamburger meat'],
#  ['other vegetables'],
#  ['butter'],
#  ['sliced cheese', 'pastry'],
#  ['chicken'],
#  ['sausage'],
#  ['citrus fruit'],
#  ['butter milk'],
#  ['fish'],
#  ['rollsbuns'],
#  ['oil', 'rollsbuns', 'frozen vegetables'],
#  ['coffee', 'newspapers', 'tropical fruit'],
#  ['soda', 'white bread', 'bottled water'],
#  ['other vegetables', 'snack products'],
#  ['misc beverages'],
#  ['napkins'],
#  ['root vegetables'],
#  ['rollsbuns'],
#  ['chocolate marshmallow', 'citrus fruit', 'butter'],
#  ['soda'],
#  ['root vegetables'],
#  ['bottled beer'],
#  ['coffee', 'whole milk', 'meat'],
#  ['other vegetables', 'frozen meals', 'chicken'],
#  ['frankfurter', 'pip fruit'],
#  ['grapes', 'ice cream', 'citrus fruit', 'whippedsour cream'],
#  ['citrus fruit', 'packaged fruitvegetables'],
#  ['root vegetables', 'spread cheese'],
#  ['salty snack'],
#  ['frankfurter',
#   'sausage',
#   'frozen meals',
#   'cat food',
#   'misc beverages',
#   'whole milk'],
#  ['whippedsour cream', 'sausage'],
#  ['onions', 'mustard'],
#  ['fruitvegetable juice'],
#  ['shopping bags'],
#  ['hard cheese'],
#  ['specialty cheese'],
#  ['semifinished bread', 'white wine'],
#  ['butter milk'],
#  ['soda'],
#  ['processed cheese'],
#  ['uhtmilk'],
#  ['root vegetables'],
#  ['house keeping products'],
#  ['cream cheese '],
#  ['dishes'],
#  ['salty snack'],
#  ['yogurt'],
#  ['bottled water'],
#  ['citrus fruit', 'rollsbuns', 'root vegetables', 'fruitvegetable juice'],
#  ['pip fruit'],
#  ['rollsbuns', 'yogurt'],
#  ['other vegetables'],
#  ['whole milk'],
#  ['candy', 'other vegetables', 'whole milk', 'tropical fruit'],
#  ['rollsbuns'],
#  ['frozen vegetables'],
#  ['chocolate marshmallow'],
#  ['other vegetables', 'rollsbuns'],
#  ['whole milk'],
#  ['brown bread'],
#  ['white wine'],
#  ['brown bread'],
#  ['pork'],
#  ['dessert', 'butter'],
#  ['salty snack', 'hard cheese'],
#  ['salty snack'],
#  ['rollsbuns'],
#  ['candy'],
#  ['rollsbuns'],
#  ['oil'],
#  ['other vegetables', 'long life bakery product'],
#  ['whippedsour cream'],
#  ['tropical fruit'],
#  ['ham'],
#  ['rollsbuns'],
#  ['canned beer'],
#  ['grapes', 'pastry'],
#  ['soft cheese'],
#  ['canned fruit', 'pip fruit', 'root vegetables'],
#  ['citrus fruit', 'citrus fruit'],
#  ['waffles', 'female sanitary products', 'citrus fruit'],
#  ['curd', 'baking powder', 'shopping bags'],
#  ['pork', 'specialty bar'],
#  ['whole milk'],
#  ['whole milk', 'bottled beer'],
#  ['condensed milk'],
#  ['citrus fruit', 'frankfurter', 'salt'],
#  ['rollsbuns'],
#  ['mustard', 'bottled water', 'root vegetables', 'long life bakery product'],
#  ['ham', 'condensed milk', 'chewing gum', 'soda'],
#  ['canned beer', 'beef'],
#  ['pip fruit'],
#  ['whole milk'],
#  ['grapes', 'rollsbuns'],
#  ['whole milk'],
#  ['instant coffee'],
#  ['tropical fruit'],
#  ['ham'],
#  ['canned beer', 'newspapers', 'dessert'],
#  ['detergent', 'yogurt', 'ham', 'whippedsour cream'],
#  ['whippedsour cream'],
#  ['processed cheese'],
#  ['roll products '],
#  ['chicken'],
#  ['condensed milk'],
#  ['butter milk'],
#  ['whole milk'],
#  ['uhtmilk'],
#  ['whole milk', 'fruitvegetable juice'],
#  ['frozen meals', 'brown bread', 'sausage'],
#  ['sausage', 'other vegetables', 'curd', 'ham'],
#  ['chicken', 'instant food products'],
#  ['coffee'],
#  ['spread cheese'],
#  ['other vegetables'],
#  ['other vegetables'],
#  ['frozen vegetables'],
#  ['whole milk'],
#  ['pot plants'],
#  ['whole milk', 'rollsbuns'],
#  ['spices'],
#  ['fruitvegetable juice'],
#  ['other vegetables', 'napkins', 'white bread', 'soda'],
#  ['margarine'],
#  ['pastry', 'ham'],
#  ['redblush wine', 'dog food'],
#  ['whole milk', 'chicken'],
#  ['fruitvegetable juice', 'white bread'],
#  ['oil'],
#  ['bottled water', 'bottled water'],
#  ['rollsbuns'],
#  ['sweet spreads'],
#  ['berries'],
#  ['pip fruit'],
#  ['soda', 'other vegetables', 'pastry', 'frankfurter', 'bottled water'],
#  ['chewing gum', 'root vegetables'],
#  ['domestic eggs', 'bottled water', 'whole milk'],
#  ['canned beer', 'shopping bags'],
#  ['frozen vegetables', 'soda'],
#  ['tropical fruit', 'rollsbuns'],
#  ['root vegetables'],
#  ['bottled water', 'whippedsour cream', 'chewing gum'],
#  ['butter milk'],
#  ['flour', 'instant coffee'],
#  ['whole milk'],
#  ['newspapers', 'ice cream'],
#  ['curd'],
#  ['onions'],
#  ['soft cheese'],
#  ['soda'],
#  ['root vegetables'],
#  ['whippedsour cream', 'newspapers', 'whippedsour cream'],
#  ['domestic eggs'],
#  ['newspapers'],
#  ['frankfurter'],
#  ['dishes', 'root vegetables'],
#  ['whole milk', 'turkey'],
#  ['pastry', 'whole milk'],
#  ['onions'],
#  ['whole milk', 'beef'],
#  ['curd'],
#  ['chocolate', 'whole milk'],
#  ['hard cheese'],
#  ['butter', 'pastry', 'whole milk'],
#  ['whole milk', 'canned vegetables'],
#  ['bottled water'],
#  ['soda'],
#  ['specialty bar'],
#  ['butter milk'],
#  ['other vegetables'],
#  ['sweet spreads', 'other vegetables'],
#  ['pastry', 'beef', 'whole milk', 'other vegetables'],
#  ['whole milk'],
#  ['yogurt', 'other vegetables'],
#  ['flour', 'sugar'],
#  ['whole milk'],
#  ['other vegetables', 'waffles'],
#  ['pastry', 'yogurt'],
#  ['white bread', 'canned beer', 'whole milk', 'rollsbuns', 'tropical fruit'],
#  ['misc beverages'],
#  ['white bread', 'whole milk'],
#  ['grapes', 'whole milk', 'curd', 'soups'],
#  ['frozen vegetables', 'curd', 'canned beer'],
#  ['bottled water'],
#  ['candy'],
#  ['rollsbuns'],
#  ['pip fruit', 'salty snack'],
#  ['newspapers'],
#  ['cream cheese ', 'soda'],
#  ['meat', 'mayonnaise'],
#  ['frankfurter'],
#  ['root vegetables'],
#  ['oil'],
#  ['chocolate', 'pip fruit'],
#  ['onions'],
#  ['canned beer', 'domestic eggs'],
#  ['cake bar'],
#  ['rollsbuns', 'long life bakery product'],
#  ['soda'],
#  ['other vegetables'],
#  ['beverages', 'chocolate'],
#  ['rollsbuns'],
#  ['curd'],
#  ['coffee'],
#  ['onions'],
#  ['rollsbuns'],
#  ['domestic eggs', 'canned beer', 'soda'],
#  ['instant coffee'],
#  ['bottled water'],
#  ['coffee', 'beef'],
#  ['curd', 'whippedsour cream'],
#  ['pip fruit', 'chocolate', 'root vegetables', 'yogurt', 'other vegetables'],
#  ['sugar', 'pork'],
#  ['soda'],
#  ['specialty bar'],
#  ['soda'],
#  ['rollsbuns'],
#  ['cake bar', 'uhtmilk'],
#  ['other vegetables'],
#  ['pastry', 'house keeping products'],
#  ['bottled beer'],
#  ['yogurt', 'rollsbuns', 'sausage'],
#  ['other vegetables'],
#  ['bottled water'],
#  ['long life bakery product'],
#  ['curd'],
#  ['tropical fruit'],
#  ['other vegetables', 'pork'],
#  ['soda'],
#  ['sausage'],
#  ['tropical fruit', 'shopping bags', 'pork'],
#  ['sugar', 'specialty chocolate'],
#  ['whole milk', 'sausage'],
#  ['other vegetables', 'other vegetables'],
#  ['beverages'],
#  ['frozen meals', 'canned vegetables'],
#  ['rollsbuns'],
#  ['soda', 'canned beer'],
#  ['brown bread'],
#  ['fruitvegetable juice', 'cling filmbags'],
#  ['whippedsour cream', 'frankfurter'],
#  ['whole milk', 'long life bakery product'],
#  ['frozen meals', 'tropical fruit', 'sausage', 'oil', 'bottled water'],
#  ['whole milk'],
#  ['sausage', 'sparkling wine'],
#  ['bottled beer'],
#  ['pasta'],
#  ['white bread'],
#  ['citrus fruit', 'pastry', 'frankfurter'],
#  ['white wine'],
#  ['hamburger meat'],
#  ['whole milk'],
#  ['whole milk', 'shopping bags', 'whole milk', 'snack products'],
#  ['specialty chocolate',
#   'shopping bags',
#   'yogurt',
#   'kitchen towels',
#   'whippedsour cream'],
#  ['bottled water', 'rollsbuns', 'other vegetables'],
#  ['margarine', 'root vegetables'],
#  ['cream cheese ', 'soda'],
#  ['bottled water'],
#  ['canned beer'],
#  ['soda'],
#  ['whole milk'],
#  ['fruitvegetable juice'],
#  ['long life bakery product'],
#  ['sliced cheese', 'fruitvegetable juice'],
#  ['oil', 'zwieback'],
#  ['uhtmilk', 'other vegetables'],
#  ['pip fruit', 'uhtmilk'],
#  ['butter'],
#  ['yogurt'],
#  ['butter'],
#  ['root vegetables', 'newspapers'],
#  ['domestic eggs'],
#  ['oil', 'salty snack', 'syrup'],
#  ['canned beer'],
#  ['rollsbuns'],
#  ['beverages'],
#  ['citrus fruit', 'frankfurter', 'newspapers'],
#  ['hard cheese'],
#  ['rollsbuns'],
#  ['candy'],
#  ['canned beer', 'yogurt'],
#  ['rollsbuns', 'whole milk'],
#  ['curd'],
#  ['shopping bags'],
#  ['grapes'],
#  ['berries'],
#  ['instant coffee', 'citrus fruit'],
#  ['spices', 'citrus fruit', 'newspapers'],
#  ['ham'],
#  ['yogurt', 'bottled water'],
#  ['specialty chocolate', 'root vegetables'],
#  ['potato products'],
#  ['whole milk', 'onions'],
#  ['sliced cheese'],
#  ['soda'],
#  ['other vegetables'],
#  ['uhtmilk'],
#  ['pip fruit'],
#  ['packaged fruitvegetables', 'bottled beer'],
#  ['whole milk'],
#  ['citrus fruit'],
#  ['hamburger meat'],
#  ['yogurt', 'other vegetables'],
#  ['citrus fruit', 'specialty bar', 'yogurt'],
#  ['butter'],
#  ['salty snack'],
#  ['waffles'],
#  ['margarine'],
#  ['beef'],
#  ['fruitvegetable juice', 'canned beer'],
#  ['salty snack'],
#  ['shopping bags', 'whole milk'],
#  ['cream cheese ', 'onions', 'oil', 'frankfurter'],
#  ['beef', 'whole milk'],
#  ['other vegetables'],
#  ['rollsbuns'],
#  ['shopping bags', 'tropical fruit'],
#  ['candles'],
#  ['butter', 'newspapers'],
#  ['pastry'],
#  ['tropical fruit'],
#  ['frankfurter'],
#  ['cream cheese ', 'rollsbuns'],
#  ['newspapers', 'shopping bags', 'whole milk'],
#  ['whole milk',
#   'hamburger meat',
#   'root vegetables',
#   'hygiene articles',
#   'meat'],
#  ['rollsbuns', 'pip fruit'],
#  ['frankfurter'],
#  ['brown bread'],
#  ['fruitvegetable juice'],
#  ['salty snack'],
#  ['whole milk'],
#  ['margarine'],
#  ['instant coffee', 'hamburger meat', 'bottled beer', 'yogurt'],
#  ['yogurt'],
#  ['kitchen towels'],
#  ['tropical fruit'],
#  ['mayonnaise', 'margarine'],
#  ['rollsbuns'],
#  ['tropical fruit', 'other vegetables'],
#  ['hygiene articles'],
#  ['flour', 'beef'],
#  ['ham'],
#  ['liquor'],
#  ['whippedsour cream'],
#  ['shopping bags'],
#  ['domestic eggs', 'root vegetables', 'rollsbuns', 'frozen vegetables'],
#  ['whole milk'],
#  ['grapes'],
#  ['butter milk'],
#  ['grapes', 'ice cream'],
#  ['specialty bar'],
#  ['chocolate marshmallow', 'curd'],
#  ['bottled beer'],
#  ['salty snack'],
#  ['bottled water'],
#  ['other vegetables'],
#  ['specialty bar', 'tropical fruit'],
#  ['dessert'],
#  ['sausage'],
#  ['whole milk'],
#  ['packaged fruitvegetables'],
#  ['tropical fruit'],
#  ['citrus fruit'],
#  ['popcorn', 'beverages'],
#  ['hamburger meat'],
#  ['other vegetables', 'sausage'],
#  ['root vegetables'],
#  ['sausage'],
#  ['newspapers'],
#  ['shopping bags'],
#  ['salty snack'],
#  ['bottled water', 'zwieback'],
#  ['tropical fruit'],
#  ['butter', 'yogurt'],
#  ['pork'],
#  ['yogurt'],
#  ['sliced cheese'],
#  ['root vegetables', 'bottled water', 'waffles'],
#  ['bottled beer'],
#  ['rollsbuns'],
#  ['whole milk'],
#  ['frankfurter'],
#  ['root vegetables'],
#  ['instant food products'],
#  ['pasta', 'domestic eggs'],
#  ['canned beer'],
#  ['margarine', 'yogurt'],
#  ['liquor', 'uhtmilk'],
#  ['uhtmilk', 'whole milk'],
#  ['shopping bags', 'yogurt'],
#  ['packaged fruitvegetables'],
#  ['bottled beer', 'liquor appetizer', 'misc beverages'],
#  ['cream cheese ', 'liquor'],
#  ['pot plants'],
#  ['chicken', 'whippedsour cream', 'pastry'],
#  ['soft cheese'],
#  ['soda'],
#  ['berries', 'other vegetables'],
#  ['tropical fruit', 'shopping bags', 'onions'],
#  ['berries', 'packaged fruitvegetables'],
#  ['rollsbuns'],
#  ['yogurt'],
#  ['yogurt'],
#  ['rollsbuns'],
#  ['pip fruit'],
#  ['soda', 'sugar'],
#  ['cream cheese '],
#  ['canned fish', 'beverages'],
#  ['pip fruit', 'meat'],
#  ['yogurt'],
#  ['tropical fruit'],
#  ['root vegetables', 'rollsbuns', 'canned beer'],
#  ['root vegetables'],
#  ['soda', 'beef', 'sausage'],
#  ['beef'],
#  ['soda', 'candles'],
#  ['soda', 'oil', 'soft cheese'],
#  ['dish cleaner', 'chicken'],
#  ['other vegetables', 'onions', 'pip fruit', 'yogurt'],
#  ['cling filmbags'],
#  ['popcorn', 'rollsbuns'],
#  ['white bread'],
#  ['grapes'],
#  ['brown bread', 'vinegar'],
#  ['whole milk'],
#  ['soda'],
#  ['frozen vegetables'],
#  ['detergent'],
#  ['frankfurter'],
#  ['other vegetables', 'hard cheese'],
#  ['spices'],
#  ['whippedsour cream', 'yogurt'],
#  ['hard cheese'],
#  ['cat food'],
#  ['sausage'],
#  ['bottled beer'],
#  ['whippedsour cream', 'misc beverages'],
#  ['packaged fruitvegetables', 'specialty bar'],
#  ['hygiene articles'],
#  ['sausage'],
#  ['shopping bags'],
#  ['rollsbuns'],
#  ['citrus fruit', 'baking powder'],
#  ['frankfurter'],
#  ['whole milk'],
#  ['root vegetables'],
#  ['fruitvegetable juice'],
#  ['chocolate'],
#  ['shopping bags', 'specialty bar'],
#  ['whole milk', 'pork'],
#  ['rollsbuns', 'frankfurter', 'canned fish'],
#  ['sausage'],
#  ['fruitvegetable juice'],
#  ['canned beer'],
#  ['other vegetables'],
#  ['finished products', 'whole milk', 'fruitvegetable juice'],
#  ['pork'],
#  ['white wine'],
#  ['curd'],
#  ['citrus fruit'],
#  ['canned beer', 'potato products'],
#  ['pet care'],
#  ['hair spray', 'dessert', 'yogurt', 'processed cheese'],
#  ['flower seeds'],
#  ['sugar'],
#  ['brown bread', 'pot plants'],
#  ['bottled beer'],
#  ['bottled water'],
#  ['uhtmilk', 'liquor'],
#  ['fruitvegetable juice'],
#  ['other vegetables'],
#  ['candy', 'whole milk', 'domestic eggs'],
#  ['ham'],
#  ['fruitvegetable juice'],
#  ['salty snack', 'whole milk'],
#  ['domestic eggs', 'chicken'],
#  ['bottled beer'],
#  ['bottled beer'],
#  ['shopping bags'],
#  ['whole milk', 'pasta'],
#  ['soda'],
#  ['bottled beer'],
#  ['pastry'],
#  ['shopping bags'],
#  ['sausage'],
#  ['rollsbuns', 'bottled beer'],
#  ['pork'],
#  ['other vegetables', 'beef'],
#  ['berries'],
#  ['yogurt'],
#  ['salty snack'],
#  ['margarine', 'whole milk'],
#  ['tropical fruit'],
#  ['dish cleaner', 'margarine', 'napkins'],
#  ...]

# %%
# encode test transactions
encoded_array_test = encoder.transform(test_transactions)
df_test = pd.DataFrame(encoded_array_test, columns=encoder.columns_)
df_test
# Out:
#       abrasive cleaner  artif sweetener  baby cosmetics   bags  baking powder  \
# 0                False            False           False  False          False
# 1                False            False           False  False          False
# 2                False            False           False  False          False
# 3                False            False           False  False          False
# 4                False            False           False  False          False
# ...                ...              ...             ...    ...            ...
# 7683             False            False           False  False          False
# 7684             False            False           False  False          False
# 7685             False            False           False  False          False
# 7686             False            False           False  False          False
# 7687             False            False           False  False          False
#
#       bathroom cleaner   beef  berries  beverages  bottled beer  ...  uhtmilk  \
# 0                False  False    False      False         False  ...    False
# 1                False  False    False      False         False  ...    False
# 2                False  False    False      False         False  ...    False
# 3                False  False    False      False         False  ...    False
# 4                False  False    False      False         False  ...    False
# ...                ...    ...      ...        ...           ...  ...      ...
# 7683             False  False    False      False         False  ...    False
# 7684             False  False     True      False         False  ...    False
# 7685             False  False    False      False         False  ...    False
# 7686             False  False    False      False          True  ...    False
# 7687             False  False    False      False         False  ...    False
#
#       vinegar  waffles  whippedsour cream  whisky  white bread  white wine  \
# 0       False    False              False   False        False       False
# 1       False    False              False   False        False       False
# 2       False    False              False   False        False       False
# 3       False    False              False   False        False       False
# 4       False    False              False   False        False       False
# ...       ...      ...                ...     ...          ...         ...
# 7683    False    False              False   False        False       False
# 7684    False    False              False   False        False       False
# 7685    False    False               True   False        False       False
# 7686    False    False              False   False        False       False
# 7687    False    False              False   False        False       False
#
#       whole milk  yogurt  zwieback
# 0           True   False     False
# 1           True   False     False
# 2          False   False     False
# 3          False   False     False
# 4          False   False     False
# ...          ...     ...       ...
# 7683       False   False     False
# 7684       False    True     False
# 7685       False   False     False
# 7686       False   False     False
# 7687       False   False     False
#
# [7688 rows x 167 columns]

# %%
# function to apply rules to test data
def apply_rules(transactions, rules):

    results = []
    for _, rule in rules.iterrows():

        antecedents = set(rule['antecedents'])
        print(f"{antecedents} -> {set(rule['consequents'])}")
        check_rule = transactions.apply(lambda x: antecedents.issubset(set(x.index[x])), axis=1)

        if check_rule.any():
            results.append({
                'rule': f"{set(rule['antecedents'])} -> {set(rule['consequents'])}",
                'support': rule['support'],
                'confidence': rule['confidence'],
                'lift': rule['lift'],
                'coverage': check_rule.sum()
            })

    return pd.DataFrame(results)


# apply rules to test data
rule_applications = apply_rules(df_test, rules)

print("\nUpdated rule applications:\n", rule_applications)
# Out:
# {'whole milk'} -> {'rollsbuns'}
# {'rollsbuns'} -> {'whole milk'}
# {'yogurt'} -> {'whole milk'}
# {'sausage'} -> {'whole milk'}
# {'bottled water'} -> {'whole milk'}
# {'bottled beer'} -> {'whole milk'}
# {'canned beer'} -> {'whole milk'}
# {'butter'} -> {'whole milk'}
# {'sausage'} -> {'soda'}
# {'bottled water'} -> {'rollsbuns'}
# {'citrus fruit'} -> {'other vegetables'}
# {'frankfurter'} -> {'whole milk'}
# {'shopping bags'} -> {'rollsbuns'}
# {'frankfurter'} -> {'other vegetables'}
# {'bottled beer'} -> {'other vegetables'}
# {'fruitvegetable juice'} -> {'whole milk'}
# {'shopping bags'} -> {'soda'}
# {'pip fruit'} -> {'rollsbuns'}
# {'bottled beer'} -> {'rollsbuns'}
# {'frozen vegetables'} -> {'whole milk'}
# {'pork'} -> {'other vegetables'}
# {'domestic eggs'} -> {'other vegetables'}
# {'brown bread'} -> {'rollsbuns'}
# {'frankfurter'} -> {'soda'}
# {'white bread'} -> {'whole milk'}
# {'pork'} -> {'rollsbuns'}
# {'chicken'} -> {'rollsbuns'}
# {'frozen vegetables'} -> {'other vegetables'}
# {'fruitvegetable juice'} -> {'rollsbuns'}
# {'ham'} -> {'whole milk'}
# {'butter'} -> {'soda'}
# {'coffee'} -> {'soda'}
# {'cream cheese '} -> {'whole milk'}
# {'margarine'} -> {'rollsbuns'}
# {'white bread'} -> {'other vegetables'}
# {'frozen vegetables'} -> {'rollsbuns'}
# {'uhtmilk'} -> {'whole milk'}
# {'chocolate'} -> {'rollsbuns'}
# {'white bread'} -> {'rollsbuns'}
# {'specialty chocolate'} -> {'whole milk'}
# {'waffles'} -> {'whole milk'}
# {'berries'} -> {'other vegetables'}
# {'waffles'} -> {'rollsbuns'}
# {'sugar'} -> {'whole milk'}
# {'salty snack'} -> {'rollsbuns'}
# {'candy'} -> {'whole milk'}
# {'uhtmilk'} -> {'other vegetables'}
# {'napkins'} -> {'soda'}
# {'frozen meals'} -> {'other vegetables'}
# {'meat'} -> {'other vegetables'}
# {'hamburger meat'} -> {'soda'}
# {'grapes'} -> {'other vegetables'}
# {'oil'} -> {'whole milk'}
# {'ham'} -> {'other vegetables'}
# {'herbs'} -> {'whole milk'}
# {'meat'} -> {'rollsbuns'}
# {'oil'} -> {'soda'}
# {'soda', 'whole milk'} -> {'rollsbuns'}
# {'soda', 'rollsbuns'} -> {'whole milk'}
# {'whole milk', 'rollsbuns'} -> {'soda'}
# {'hard cheese'} -> {'rollsbuns'}
# {'processed cheese'} -> {'rollsbuns'}
# {'detergent'} -> {'whole milk'}
# {'specialty bar'} -> {'other vegetables'}
# {'semifinished bread'} -> {'whole milk'}
# {'hard cheese'} -> {'yogurt'}
# {'specialty chocolate'} -> {'tropical fruit'}
# {'grapes'} -> {'soda'}
# {'hygiene articles'} -> {'rollsbuns'}
# {'redblush wine'} -> {'other vegetables'}
# {'redblush wine'} -> {'rollsbuns'}
# {'sliced cheese'} -> {'sausage'}
# {'ice cream'} -> {'rollsbuns'}
# {'soda', 'other vegetables'} -> {'rollsbuns'}
# {'soda', 'rollsbuns'} -> {'other vegetables'}
# {'other vegetables', 'rollsbuns'} -> {'soda'}
# {'specialty bar'} -> {'yogurt'}
# {'other vegetables', 'whole milk'} -> {'rollsbuns'}
# {'other vegetables', 'rollsbuns'} -> {'whole milk'}
# {'sliced cheese'} -> {'root vegetables'}
# {'sausage', 'whole milk'} -> {'yogurt'}
# {'sausage', 'yogurt'} -> {'whole milk'}
# {'whole milk', 'yogurt'} -> {'sausage'}
# {'soda', 'whole milk'} -> {'yogurt'}
# {'soda', 'yogurt'} -> {'whole milk'}
# {'whole milk', 'yogurt'} -> {'soda'}
# {'specialty bar'} -> {'tropical fruit'}
# {'condensed milk'} -> {'other vegetables'}
# {'canned fish'} -> {'whole milk'}
# {'whole milk', 'yogurt'} -> {'rollsbuns'}
# {'rollsbuns', 'yogurt'} -> {'whole milk'}
# {'soft cheese'} -> {'rollsbuns'}
# {'sausage', 'whole milk'} -> {'rollsbuns'}
# {'sausage', 'rollsbuns'} -> {'whole milk'}
# {'detergent'} -> {'yogurt'}
# {'chewing gum'} -> {'rollsbuns'}
# {'cat food'} -> {'rollsbuns'}
# {'processed cheese'} -> {'other vegetables'}
# {'other vegetables', 'bottled water'} -> {'whole milk'}
# {'whole milk', 'bottled water'} -> {'other vegetables'}
# {'soft cheese'} -> {'yogurt'}
# {'sausage', 'soda'} -> {'whole milk'}
# {'sausage', 'whole milk'} -> {'soda'}
# {'pastry', 'whole milk'} -> {'rollsbuns'}
# {'pastry', 'rollsbuns'} -> {'whole milk'}
# {'frozen vegetables', 'other vegetables'} -> {'whole milk'}
# {'frozen vegetables', 'whole milk'} -> {'other vegetables'}
# {'seasonal products'} -> {'soda'}
# {'other vegetables', 'frankfurter'} -> {'whole milk'}
# {'whole milk', 'frankfurter'} -> {'other vegetables'}
# {'soft cheese'} -> {'other vegetables'}
# {'sausage', 'other vegetables'} -> {'whole milk'}
# {'sausage', 'whole milk'} -> {'other vegetables'}
# {'other vegetables', 'yogurt'} -> {'rollsbuns'}
# {'rollsbuns', 'yogurt'} -> {'other vegetables'}
# {'other vegetables', 'rollsbuns'} -> {'yogurt'}
# {'packaged fruitvegetables'} -> {'rollsbuns'}
# {'pickled vegetables'} -> {'rollsbuns'}
# {'processed cheese'} -> {'yogurt'}
# {'soda', 'canned beer'} -> {'whole milk'}
# {'canned beer', 'whole milk'} -> {'soda'}
# {'liquor appetizer'} -> {'whole milk'}
#
# Updated rule applications:
#                                            rule   support  confidence  \
# 0              {'whole milk'} -> {'rollsbuns'}  0.014940    0.105890
# 1              {'rollsbuns'} -> {'whole milk'}  0.014940    0.148376
# 2                 {'yogurt'} -> {'whole milk'}  0.011227    0.143341
# 3                {'sausage'} -> {'whole milk'}  0.009017    0.165584
# 4          {'bottled water'} -> {'whole milk'}  0.008310    0.144838
# ..                                         ...       ...         ...
# 117    {'pickled vegetables'} -> {'rollsbuns'}  0.001061    0.127660
# 118         {'processed cheese'} -> {'yogurt'}  0.001061    0.105263
# 119  {'soda', 'canned beer'} -> {'whole milk'}  0.001061    0.307692
# 120  {'canned beer', 'whole milk'} -> {'soda'}  0.001061    0.166667
# 121     {'liquor appetizer'} -> {'whole milk'}  0.001061    0.266667
#
#          lift  coverage
# 0    1.051646       775
# 1    1.051646       514
# 2    1.015960       402
# 3    1.173616       284
# 4    1.026573       264
# ..        ...       ...
# 117  1.267853        40
# 118  1.343947        38
# 119  2.180837         7
# 120  1.853818         9
# 121  1.890058        22
#
# [122 rows x 5 columns]

# %%
# evaluate the rules

if not rule_applications.empty:

    # calculate overall coverage
    total_transactions = df_test.shape[0]
    covered_transactions = rule_applications['coverage'].sum()
    coverage_percentage = (covered_transactions / total_transactions) * 100

    # calculate average support, confidence, and lift for applicable rules
    avg_support = rule_applications['support'].mean()
    avg_confidence = rule_applications['confidence'].mean()
    avg_lift = rule_applications['lift'].mean()

    print("Total transactions in test set:", total_transactions)
    print("Transactions covered by rules:", covered_transactions)
    print("Coverage percentage:", coverage_percentage)
    print("Average support of applicable rules:", avg_support)
    print("Average confidence of applicable rules:", avg_confidence)
    print("Average lift of applicable rules:", avg_lift)
    
    # detailed insights into rules with significant coverage
    significant_rules = rule_applications[rule_applications['coverage'] > (0.01 * total_transactions)] # at least 1% total transaction - 10,000 transactions if scaled up
    print("\nDetailed rules with significant coverage:\n", significant_rules)

else:
    print("No rules were applicable to the test transactions.")
# Out:
# Total transactions in test set: 7688
# Transactions covered by rules: 11317
# Coverage percentage: 147.20343392299688
# Average support of applicable rules: 0.002677412062049297
# Average confidence of applicable rules: 0.14519040999964752
# Average lift of applicable rules: 1.3292264940592076
#
# Detailed rules with significant coverage:
#                                               rule   support  confidence  \
# 0                 {'whole milk'} -> {'rollsbuns'}  0.014940    0.105890
# 1                 {'rollsbuns'} -> {'whole milk'}  0.014940    0.148376
# 2                    {'yogurt'} -> {'whole milk'}  0.011227    0.143341
# 3                   {'sausage'} -> {'whole milk'}  0.009017    0.165584
# 4             {'bottled water'} -> {'whole milk'}  0.008310    0.144838
# 5              {'bottled beer'} -> {'whole milk'}  0.006807    0.159420
# 6               {'canned beer'} -> {'whole milk'}  0.006365    0.150313
# 7                    {'butter'} -> {'whole milk'}  0.006011    0.181333
# 8                         {'sausage'} -> {'soda'}  0.005835    0.107143
# 9              {'bottled water'} -> {'rollsbuns'}  0.005835    0.101695
# 10       {'citrus fruit'} -> {'other vegetables'}  0.005658    0.116788
# 11              {'frankfurter'} -> {'whole milk'}  0.005658    0.160401
# 12             {'shopping bags'} -> {'rollsbuns'}  0.005304    0.123203
# 13        {'frankfurter'} -> {'other vegetables'}  0.005127    0.145363
# 14       {'bottled beer'} -> {'other vegetables'}  0.004950    0.115942
# 15     {'fruitvegetable juice'} -> {'whole milk'}  0.004862    0.152355
# 16                  {'shopping bags'} -> {'soda'}  0.004774    0.110883
# 17                 {'pip fruit'} -> {'rollsbuns'}  0.004774    0.108000
# 18              {'bottled beer'} -> {'rollsbuns'}  0.004420    0.103520
# 19        {'frozen vegetables'} -> {'whole milk'}  0.004243    0.159468
# 20               {'pork'} -> {'other vegetables'}  0.004243    0.126649
# 21      {'domestic eggs'} -> {'other vegetables'}  0.003978    0.115385
# 22               {'brown bread'} -> {'rollsbuns'}  0.003978    0.109756
# 23                    {'frankfurter'} -> {'soda'}  0.003890    0.110276
# 24              {'white bread'} -> {'whole milk'}  0.003713    0.170732
# 25                      {'pork'} -> {'rollsbuns'}  0.003713    0.110818
# 26                   {'chicken'} -> {'rollsbuns'}  0.003624    0.141869
# 27  {'frozen vegetables'} -> {'other vegetables'}  0.003536    0.132890
# 28      {'fruitvegetable juice'} -> {'rollsbuns'}  0.003536    0.110803
# 30                         {'butter'} -> {'soda'}  0.003359    0.101333
# 31                         {'coffee'} -> {'soda'}  0.003271    0.104225
# 32            {'cream cheese '} -> {'whole milk'}  0.003271    0.145669
# 33                 {'margarine'} -> {'rollsbuns'}  0.003271    0.106936
# 34        {'white bread'} -> {'other vegetables'}  0.003006    0.138211
# 35         {'frozen vegetables'} -> {'rollsbuns'}  0.003006    0.112957
# 36                  {'uhtmilk'} -> {'whole milk'}  0.003006    0.162679
# 37                 {'chocolate'} -> {'rollsbuns'}  0.002652    0.119522
# 38               {'white bread'} -> {'rollsbuns'}  0.002564    0.117886
# 40                  {'waffles'} -> {'whole milk'}  0.002475    0.146597
# 41            {'berries'} -> {'other vegetables'}  0.002475    0.122271
# 42                   {'waffles'} -> {'rollsbuns'}  0.002387    0.141361
# 43                    {'sugar'} -> {'whole milk'}  0.002387    0.146739
# 44               {'salty snack'} -> {'rollsbuns'}  0.002298    0.141304
# 46            {'uhtmilk'} -> {'other vegetables'}  0.002298    0.124402
# 47                        {'napkins'} -> {'soda'}  0.002210    0.101626
# 50                 {'hamburger meat'} -> {'soda'}  0.002122    0.103448
#
#         lift  coverage
# 0   1.051646       775
# 1   1.051646       514
# 2   1.015960       402
# 3   1.173616       284
# 4   1.026573       264
# 5   1.129926       192
# 6   1.065377       223
# 7   1.285240       152
# 8   1.191740       284
# 9   1.009985       264
# 10  1.048500       249
# 11  1.136877       169
# 12  1.223596       230
# 13  1.305040       169
# 14  1.040902       192
# 15  1.079846       149
# 16  1.233341       230
# 17  1.072604       232
# 18  1.028108       192
# 19  1.130268       119
# 20  1.137027       180
# 21  1.035897       166
# 22  1.090045       155
# 23  1.226587       169
# 24  1.210098       113
# 25  1.100590       180
# 26  1.408970       128
# 27  1.193060       119
# 28  1.100445       149
# 30  1.127122       152
# 31  1.159289       118
# 32  1.032463       103
# 33  1.062041       136
# 34  1.240831       113
# 35  1.121833       119
# 36  1.153026       112
# 37  1.187034       104
# 38  1.170789       113
# 40  1.039037        88
# 41  1.097720        95
# 42  1.403932        88
# 43  1.040046        81
# 44  1.403367        97
# 46  1.116853       112
# 47  1.130377        85
# 50  1.150646        95

# %% [markdown]
# ## References

# %% [markdown]
# [1] Chaudhary, S 2024, *'Market basket analysis: anticipating customer behavior'*, webpage, Turing, viewed 25 May 2024, <https://www.turing.com/kb/market-basket-analysis>.
#
# [2] Kotu, V 2019, *Data science: concepts and practice*, B Deshpande (ed.), Second edition., Morgan Kaufmann Publishers an imprint of Elsevier, Cambridge, pp. 1-570.
#
# [3] University of Adelaide 2024-1, COMP_SCI_7306 Mining Big Data - Module 9 Lecture: Association, pdf, The University of Adelaide, viewed 25 May 2024, <https://myuni.adelaide.edu.au/courses/91968/files/14319270?module_item_id=3274647>.
#
# [4] University of Adelaide 2024-2, COMP_SCI_7306 Mining Big Data - Module 10 Workshop: Association Patterns, Python notebook, The University of Adelaide, viewed 25 May 2024, <https://myuni.adelaide.edu.au/courses/91968/files/14319255?wrap=1>.
#
# [5] Garg, A 2018, *'Complete guide to Association Rules'*, webpage, Towards Data Science, viewed 25 May 2024, <https://towardsdatascience.com/association-rules-2-aa9a77241654>.
